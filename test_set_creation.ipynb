# %% [markdown]
# # Creating tabular FEVER test sets from preprocessed tabular data
#
# **Henry Zelenak | Last updated: 05/12/2025**

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import nltk  # Make sure NLTK is installed and data downloaded (e.g., nltk.download('punkt'))
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import openai  # For LLM interaction
from openai import OpenAI
import numpy as np
from nltk import Tree, pos_tag, word_tokenize, ne_chunk
from nltk.corpus import stopwords
import numpy as np
from nltk import RegexpParser
import json
import tqdm
import ast

# Download the necessary NLTK data files
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.download('stopwords')
nltk.download('treebank')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ## Add data sources

# %%
# Mount google drive
from google.colab import drive
import gc

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd ./drive/My Drive/SUNY_Poly_DSA598/datasets/FEVER/
# Out:
# [Errno 2] No such file or directory: './drive/My Drive/SUNY_Poly_DSA598/datasets/FEVER/'
# /content/drive/My Drive/SUNY_Poly_DSA598/datasets/FEVER

# %%
# !pwd
# Out:
# /content/drive/My Drive/SUNY_Poly_DSA598/datasets/FEVER

# %%
def load_jsonl(file_path, encoding='utf-8'):
    """Loads a JSON Lines file into a list of Python objects."""
    data = []
    with open(file_path, 'r', encoding=encoding) as f:  # Specify encoding for safety
        for line in f:
            data.append(json.loads(line))  # Parse each line individually
    return data

# %%
# Data paths (replace with your actual paths if different)
train_clf_path = f"tabular_sets/tabular_clf_paper_dev_train/v1_segmented_sentIDs_n3461_04-04_002.csv"
valid_clf_path = f"tabular_sets/tabular_clf_paper_dev_valid/v1_segmented_sentIDs_n1482_04-04_002.csv"
train_sentEx_path = f"tabular_sets/tabular_sentEx_paper_dev_train/v1_segmented_sentIDs_n3461_04-04_002.csv"
valid_sentEx_path = f"tabular_sets/tabular_sentEx_paper_dev_valid/v1_segmented_sentIDs_n1482_04-04_002.csv"
test_path = f"paper_test.jsonl"
train_path = f"paper_dev.jsonl"

# Load datasets
train_clf = pd.read_csv(train_clf_path)
valid_clf = pd.read_csv(valid_clf_path)
train_sentEx = pd.read_csv(train_sentEx_path)
valid_sentEx = pd.read_csv(valid_sentEx_path)
test_jsonl = load_jsonl(test_path)
train_jsonl = load_jsonl(train_path)

# %%
# Show the distribution of labels
print(f"SentEx train set label distribution:")
print(train_sentEx['label'].value_counts())
print(f"SentEx valid set label distribution:")
print(valid_sentEx['label'].value_counts())
print(f"CLF train set label distribution:")
print(train_clf['label'].value_counts())
print(f"CLF valid set label distribution:")
print(valid_clf['label'].value_counts())

# Balance the labels by reducing each to the minimum count
min_count = min(train_sentEx['label'].value_counts())
train_sentEx = train_sentEx.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
min_count = min(valid_sentEx['label'].value_counts())
valid_sentEx = valid_sentEx.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
min_count = min(train_clf['label'].value_counts())
train_clf = train_clf.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
min_count = min(valid_clf['label'].value_counts())
valid_clf = valid_clf.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

# Show the distribution of labels after balancing
print(f"SentEx train set label distribution after balancing:")
print(train_sentEx['label'].value_counts())
print(f"SentEx valid set label distribution after balancing:")
print(valid_sentEx['label'].value_counts())
print(f"CLF train set label distribution after balancing:")
print(train_clf['label'].value_counts())
print(f"CLF valid set label distribution after balancing:")
print(valid_clf['label'].value_counts())
# Out:
# SentEx train set label distribution:
# label
# SUPPORTS           1156
# REFUTES            1156
# NOT ENOUGH INFO    1149
# Name: count, dtype: int64
# SentEx valid set label distribution:
# label
# SUPPORTS           495
# REFUTES            495
# NOT ENOUGH INFO    488
# Name: count, dtype: int64
# CLF train set label distribution:
# label
# SUPPORTS           1156
# REFUTES            1156
# NOT ENOUGH INFO    1149
# Name: count, dtype: int64
# CLF valid set label distribution:
# label
# SUPPORTS           496
# REFUTES            496
# NOT ENOUGH INFO    486
# Name: count, dtype: int64
# SentEx train set label distribution after balancing:
# label
# NOT ENOUGH INFO    1149
# REFUTES            1149
# SUPPORTS           1149
# Name: count, dtype: int64
# SentEx valid set label distribution after balancing:
# label
# NOT ENOUGH INFO    488
# REFUTES            488
# SUPPORTS           488
# Name: count, dtype: int64
# CLF train set label distribution after balancing:
# label
# NOT ENOUGH INFO    1149
# REFUTES            1149
# SUPPORTS           1149
# Name: count, dtype: int64
# CLF valid set label distribution after balancing:
# label
# NOT ENOUGH INFO    486
# REFUTES            486
# SUPPORTS           486
# Name: count, dtype: int64
# <ipython-input-11-711202d98b5e>:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_sentEx = train_sentEx.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
# <ipython-input-11-711202d98b5e>:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   valid_sentEx = valid_sentEx.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
# <ipython-input-11-711202d98b5e>:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train_clf = train_clf.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
# <ipython-input-11-711202d98b5e>:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   valid_clf = valid_clf.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

# %% [markdown]
# ## Functions to assemble samples from multiple parts

# %%
# Entity  extraction function
def extract_entities(text):
    """
    Extracts entities from the text using NLTK's Named Entity Chunker.

    Args:
        text (str): The input text.

    Returns:
        list of str: List of extracted entities.
    """
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.lower() not in stop_words]
    tagged_tokens = pos_tag(tokens)
    named_entities = ne_chunk(tagged_tokens)

    entities = []
    for subtree in named_entities:
        if isinstance(subtree, Tree):
            entity = " ".join([word for word, tag in subtree.leaves()])
            entities.append(entity)

    return entities


# Keyword extraction function
def extract_keywords(text):
    """
    Extracts keywords from the text using TF-IDF.

    Args:
        text (str): The input text.

    Returns:
        list of str: List of extracted keywords.
    """
    vectorizer = TfidfVectorizer(stop_words='english', max_features=10)  # Adjust max_features as needed
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = vectorizer.get_feature_names_out()
    dense = tfidf_matrix.todense()
    denselist = dense.tolist()
    # Convert the list to a NumPy array to use argsort()

    dense_array = np.array(denselist[0])
    keywords = [feature_names[i] for i in dense_array.argsort()[-5:]]  # Get top 5 keywords

    return keywords


##### SET THIS INDEX TO 0 TO START FROM THE FIRST CLAIM AFTER SHUFFLING THE DATA #####
##### IF WE SHUFFLE THE DATA USING THE SAME SEED, WE CAN DEVELOP A CONSISTENT TEST SET #####
index = 0
def get_test_claim(df, verbose=0, debug=False):
    """
    In "test" mode, gets data for a claim by matching a row in the df (which contains the claim and the wikipedia text data) to the JSONL object
    (which contains the claim and the evidence references) by the claim, returning the claim, label, evidence sentences, documents, and evidence references.

    In 'live' mode, gets data for a claim by generating a query and retrieving documents from Wikipedia. THIS MODE IS NOT COMPATIBLE WITH FEVER SCORING.

    EXAMPLE:
    {"id": 113501, "verifiable": "NOT VERIFIABLE", "label": "NOT ENOUGH INFO", "claim": "Grease had bad reviews.", "evidence": [[[133128, null, null, null]]]}
    {"id": 163803, "verifiable": "VERIFIABLE", "label": "SUPPORTS", "claim": "Ukrainian Soviet Socialist Republic was a founding participant of the UN.", "evidence": [[[296950, 288668, "Ukrainian_Soviet_Socialist_Republic", 7]], [[298602, 290067, "Ukrainian_Soviet_Socialist_Republic", 7], [298602, 290067, "United_Nations", 0]], [[300696, 291816, "Ukrainian_Soviet_Socialist_Republic", 7]], [[344347, 327887, "Ukrainian_Soviet_Socialist_Republic", 7]], [[344994, 328433, "Ukrainian_Soviet_Socialist_Republic", 7]], [[344997, 328435, "Ukrainian_Soviet_Socialist_Republic", 7]]]}
    {"id": 70041, "verifiable": "VERIFIABLE", "label": "SUPPORTS", "claim": "2 Hearts is a musical composition by Minogue.", "evidence": [[[225394, 230056, "2_Hearts_-LRB-Kylie_Minogue_song-RRB-", 0]], [[317953, 306972, "2_Hearts_-LRB-Kylie_Minogue_song-RRB-", 0]], [[319638, 308345, "2_Hearts_-LRB-Kylie_Minogue_song-RRB-", 0]], [[319643, 308348, "2_Hearts_-LRB-Kylie_Minogue_song-RRB-", 0]]]}
    {"id": 202314, "verifiable": "VERIFIABLE", "label": "REFUTES", "claim": "The New Jersey Turnpike has zero shoulders.", "evidence": [[[238335, 240393, "New_Jersey_Turnpike", 15]]]}
    """

    global index
    claim = df.iloc[index]['claim']
    documents = df.iloc[index]['full_text']
    documents = documents.split('\n')
    label = df.iloc[index]['label']
    keywords = extract_keywords(claim)  # Extract keywords from the claim
    evidence_items = df.iloc[index]['evidence_sentences']
    id = df.iloc[index]['id']

    if debug:
      print(f"DEBUG 1.1.1:")
      print(f"Evidence items: {evidence_items}")
    # Evidence items are in the format [sentence, page_title, sentence_id, entities[entity1, entity2, ...]]
    '''
    [('Despite their San Francisco Bay Area origins , they played in a Southern rock style , with lyrics about bayous , catfish , the Mississippi River , and other popular elements of Southern United States iconography , as well as political and socially-conscious lyrics about topics including the Vietnam War .', 'Creedence_Clearwater_Revival', 3, ['Vietnam War', 'Southern rock', 'San Francisco Bay Area', 'Opposition to United States involvement in the Vietnam War', 'rock', 'Mississippi River', 'rock music']), ('Creedence Clearwater Revival , often informally abbreviated to Creedence or CCR , was an American rock band active in the late 1960s and early 1970s .', 'Creedence_Clearwater_Revival', 0, ['rock', 'rock music']), ('Their musical style encompassed the roots rock , swamp rock , and blues rock genres .', 'Creedence_Clearwater_Revival', 2, ['roots rock', 'rock', 'blues rock', 'rock music', 'swamp rock'])]
    '''
    index += 1
    # Return essential information (we only need the documents, keywords, entities, claim, and label for the NOT ENOUGH INFO case, since we don't need to extract evidence sentences)
    if label == "NOT ENOUGH INFO":
        evidence_items = []
        entities = extract_entities(claim)  # Extract entities from the claim
        if verbose == 1:
          print(f"-------------------------------------------------------------")
          print(f"Claim: {claim}")
          print(f"Label: {label}")
          print(f"Evidence items: {evidence_items}")
          print(f"Documents: {documents}")
          print(f"Entities: {entities}")
          print(f"Keywords: {keywords}")
          print(f"-------------------------------------------------------------")
        return claim, label, evidence_items, documents, keywords, entities, id

    entities = []
    # Use ast.literal_eval to convert the string representation of the list to an actual list
    evidence_items = ast.literal_eval(evidence_items)
    # Extract entities from the evidence items
    for item in evidence_items:
        entities.extend(item[3])
        if debug:
          print(f"DEBUG 1.1.2:")
          print(f"\tEvidence item: {item}")
          print(f"\tEntities: {item[3]}")
          print("-_-_-_-_-_-_-_-_-_-_-_-_-_-")
    # Remove duplicates
    entities = list(set(entities))
    # Remove empty strings
    entities = [entity for entity in entities if entity]

    if verbose == 1:
        print(f"-------------------------------------------------------------")
        print(f"Claim: {claim}")
        print(f"Label: {label}")
        print(f"Evidence items: {evidence_items}")
        print(f"Documents: {documents}")
        print(f"Entities: {entities}")
        print(f"Keywords: {keywords}")
        print(f"-------------------------------------------------------------")


    return claim, label, evidence_items, documents, keywords, entities, id

# %% [markdown]
# ## Functions to create independent, randomized, and balanced test sets

# %%
# Helper function to split a dataset into three datasets, one for each label (returns three dataframes)
def split_dataset(df):
    df_supports = df[df['label'] == 'SUPPORTS']
    df_refutes = df[df['label'] == 'REFUTES']
    df_not_enough_info = df[df['label'] == 'NOT ENOUGH INFO']

    return df_supports, df_refutes, df_not_enough_info

# Assemble a 99 sample balanced test subset by running get_test_claim in a loop and appending each result to a dictionary (only claim, label, evidence_items, documents_text, and entities)
def shuffle_assemble_balanced(df, verbose=0, debug=False):

  test_set = []

  df_supports, df_refutes, df_not_enough_info = split_dataset(df)

  df_supports = df_supports.sample(frac=1, random_state=2025)
  df_refutes = df_refutes.sample(frac=1, random_state=2025)
  df_not_enough_info = df_not_enough_info.sample(frac=1, random_state=2025)

  for i in range(0, 99): # 99 claims, 33 of each label
      # Cycle between all three using i%% and if statements
      if i % 3 == 0:
          claim, label, evidence_items, documents_text, keywords, entities, id = get_test_claim(df_supports, verbose=0, debug=debug)
      if i % 3 == 1:
          claim, label, evidence_items, documents_text, keywords, entities, id = get_test_claim(df_refutes, verbose=0, debug=debug)
      if i % 3 == 2:
          claim, label, evidence_items, documents_text, keywords, entities, id = get_test_claim(df_not_enough_info, verbose=0, debug=debug)


      test_set.append(
          {
              "id": id,
              "claim": claim,
              "label": label,
              "evidence_items": evidence_items,
              "documents_text": documents_text,
              "entities": entities, # Entities are part of the FEVER data (they are more robust than our nltk entity extraction from our testing)
          } # We don't include keyword as those are not in the FEVER data (we extract them in the system)
      )
      if verbose == 1:
        print(f"Appended claim {claim} with label {label} to the test set.")
        print(f"-------------------------------------------------------------\n")


  # Convert to a dataframe
  test_set = pd.DataFrame(test_set)
  return test_set

test_sub_valid_sentEx_A = shuffle_assemble_balanced(valid_sentEx, verbose=1, debug=False)
test_sub_valid_sentEx_B = shuffle_assemble_balanced(valid_sentEx, verbose=1, debug=False)
test_sub_valid_sentEx_C = shuffle_assemble_balanced(valid_sentEx, verbose=1, debug=False)
# Out:
# Appended claim Colin Kaepernick is a starting quarterback for the San Francisco 49ers. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Private Lives is a two act comedy from 1930. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Jennifer Lopez made a wood shed. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim New Orleans Pelicans compete the southwest Division of the NBA's Western Conference. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Beach exclusively falls under the comedy genre. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Bruce Shand was awarded the Military Cross for gallantry. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Kuching is the capital and most populous city in Sarawak. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim DNA is uninvolved with Little Mix. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Fidel Castro transferred his responsibilities to his sister. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Speech recognition incorporates two things into multiple fields. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Diana, Princess of Wales has yet to be married. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Pearl Jam plays music together. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Connie Nielsen played the role of Meredith Kane. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Yara Shahidi is 32 years old. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim First Motion Picture Unit produced more than 401 films. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Trevor Griffiths was born on April 4, 1935. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Gin is not a spirit. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Shinji Mikami directed the 1999 video game Resident Evil. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tool is a rock band that formed in 1990. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Diana, Princess of Wales became known as Lady Diana Thatcher. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Trollhunters is a television horror series. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Liam Neeson received nominations for three Golden Globe Awards. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The White House Press Secretary is a junior official. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Bessie Smith was awarded a gold medal on April 15, 1894. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Kellogg's is a manufacturer. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim EA Black Box was a coach. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim "Love the Way You Lie" is Eminem's single. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Quran is an Islamic religious text. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Janet Leigh was incapable of acting. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Raees (film) stars Akshay Kumar. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The NAACP Image Award for Outstanding Supporting Actor in a Drama Series has been received by Omar Epps. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Tylenol is advertised for increasing pain. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Jewell is a rapper. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Edmund H. North won an Academy Award. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Valencia is in America. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Australia (2008 film) production lasted 2 years. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Damon Albarn collaborated with Brian Eno on his album Everyday Robots. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Edison Machine Works was barely a manufacturing company. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Murda Beatz is Irish. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Sean Penn was in crime drama films. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim A View to a Kill is the third James Bond film written by John Glen. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim David Spade starred in Roshomon. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Daggering originated in Jamaica. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The United Nations Charter was vetoed in San Francisco, United States. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Shane McMahon announced his retirement in 2009. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Private Lives is a comedy of manners from 1930 by Noel Coward. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim EA Black Box was founded in 1999. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Terry Crews played in the NFL in 2001. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tie Your Mother Down was released. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Paramore is from Texas. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Nicholas Brody is the father of Nick. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Hunchback of Notre Dame is based off of a book. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Saxony only has a population of 2 million people. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Taylor Lautner appeared on the movie poster for Avatar. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Sean Penn has acted in 13 films. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Washington Wizards lost the conference title in 1975. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Lemmy was unknown due to his appearance. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The 15th was the day the Lockhead Martin F-35 Lightning II first flew on. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Greek language is spoken only outside of Greece. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Albert S. Ruddy is born in a town call Syriati in Canada. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Stanley Williams was a person who committed crimes. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Margaret Thatcher was a squid. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Shawn Carlson is a STEM and poetry educator. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The playoffs were only missed by James Jones once. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim John Krasinski is a thespian. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Diana, Princess of Wales became known as Lady Shakespeare. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Libya is one of the top ten largest countries on its continent. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Daggering is incapable of being a form of dance. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Neil Diamond likes to be called Leslie. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Edison Machine Works was set up. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Kerplunk was released through a company other than Lookout Records. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Ashton Kutcher was in five films in 2005. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tijuana is part of the San Diego -- Tijuana metropolitan area. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Global warming causes an influx of people into populated areas due to rising sea levels. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim AMGTV has pay per view programming. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Johnny Galecki acted in Roseanne for five years. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Finding Dory was directed by Ingmar Bergman. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Dreamer (2005 film) was filmed in an American sports studio. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Chris Kyle was a sniper and a veteran. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Don Bradman had anything but declining years. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Samwell Tarly appears in a television. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim 12 million copies of Bad Romance were bought around the world. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Danger UXB is from 1981. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The New York City Landmarks Preservation Commission includes a businessman. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Danielle Cormack is from New Zealand. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Part of Dilwale Dulhania Le Jayenge was filmed in Super 8. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Winter's Tale is a romance. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim A Milli is a song by Lil Wayne. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Graffiti was released in 2007. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Kendall Jenner is a celebrity. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Rabies is infectious. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Tenacious D is made up of two Canadians. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim DJ Quik was born on January 18th, 1970 in a taxi cab. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Jennifer Lopez married a minimum of two times. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Brick (film) was directed by Michael Bay only. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Dreamer (2005 film) is an American 2005 silent film. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Sancho Panza is a fictional character in a novel written by a Spanish writer born in the 17th century. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim David Packouz was born in 1989. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Sean Penn was in romantic comedy films. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Guatemala was in a civil war from 1960 to 1996. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Smriti Mandhana was born in August. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Birthday Song (2 Chainz song) features synthesizer music. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Beach is a film that falls under the adventure drama genre. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The New York City Landmarks Preservation Commission consists of zero commissioners. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Joe Walsh was inducted into the New Museum. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Down With Love is a romantic movie. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Only forced labor slavery is a reason for human trafficking. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Goosebumps (film) was directed by a Baptist. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim South African Communist Party is a trades partner. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim House ran for 9 seasons. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Match Point explores the role of desire and striving  in life. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Rupert Murdoch has worked. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Libya is the 13th largest country in the world. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Humphrey Bogart was watching many Classic American cinema in 1999. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim G I R L is the stylized form of Girl. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Mel B died before releasing "I Want You Back". with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Marnie was directed near "The Master of Suspense" with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tamerlan Tsarnaev had a sibling. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Victoria (Dance Exponents song) was a book released in 1982. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Awkward Black Girl stars Nidhi Singh. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Efraim Diveroli sold weapons. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Kellogg's products are marketed in only one country. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Reign Over Me was withheld in 2007. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim A song on Virgin Records was released by Mel B. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Savages had no director. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Valencia is a village. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Brubaker has something to do with prison. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Drake Bell has yet to release anything. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Barry Van Dyke is an American doctor. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Helmand Province is the location of Lashkargah. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Uranium-235 was discovered by a person who was only known for discovering uranium. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Eva Green acted in Twilight. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Underdog stars an actor. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Miranda Otto began her acting career in 1886. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The 100 follows characters who are students. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Dave Gibbons is an English letterer. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Concert for Bangladesh is recognized as a highly unsuccessful and minor humanitarian aid project. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Glee.com was hosted by Community Connect Inc.. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Luis Fonsi does not go by his given name on stage. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim There are no musical or creative works in existence that have been created by Phillip Glass. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Bea Arthur was an actress, comedian, and singer from Hollywood. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Quran is a religious text. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Aparshakti Khurana refused to appear in Dangal. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim House topped the Nielsen ratings for at least three seasons. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Eva Green had a career. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Hedda Gabler's world premiere took place in a boat. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Yara Shahidi is American and Asian. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Philomena was nominated. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Nicholas Brody is a non-fictional character. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim NRG Recording Studios is a performance facility. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Edgar Wright is a person. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Humphrey Bogart is incapable of being in any films. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Daggering is a new invention. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Winter's Tale is a book. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Thomas Jefferson did not found the University of Virginia. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Michael B. Jordan is a CEO. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Bloods have distinctive hand signals. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Awkward Black Girl was created by Lena Dunham. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim A Milli is a book by a hip hop recording artist. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Roland Emmerich is gay. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Washington Wizards have won zero division titles. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Matthew Gray Gubler is a high school graduate. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim In August 1991, Brad Wilk co-founded Rage. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim A working animal is wild only. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim So You Think You Can Dance ended with over ten million viewers. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Miracle at St. Anna tells the story of four soldiers in a Tuscan village. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Topman is part of a South African multinational retailing company. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The Concert for Bangladesh withheld valuable lessons and inspiration for projects that followed. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Live Through This has sold over 1.6 million copies in the United States. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Daggering is a self defense form. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Mickey Rourke appeared in a superhero film based on a DC character. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Adventures of Pluto Nash stars at least one person that was born in the 20th century. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Byron Howard sang in the film Zootopia. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Alexandra Daddario was bullied on March 16, 1986. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Mick Thomson was in Slipknot. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Awkward Black Girl is a Pakistani comedy web series. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Dreamer (2005 film) is an American sports silent film. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Connie Nielsen is a film actress. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Sancho Panza is a character who appears exclusively in Harry Potter and the Chamber of Secrets. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Craig David received a letter from the President. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Poldark has three series. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Star Trek: Discovery is the second series since Star Trek enterprise. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Basildon has residents that work in West London. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Matteo Renzi was once the Prime Minister of Italy. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Ed Wood is about the eponymous wrestler. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Earl Scruggs was a pacifist. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Jack Falahee was born. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Harvard University is small. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Paris (Paris Hilton album) incorporates elements of a music genre that originated in a club in the late 1960s. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Justin Chatwin performs as an actor. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Luis Fonsi is Chinese. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim NRG Recording Studios is a podcast recording facility. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Amyotrophic lateral sclerosis is a disease. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Sancho Panza is a fictional character in a novel written by an Australian writer born in 1616. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The Greek language is spoken in the United Kingdom. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Off the Wall won its singer a Grammy Award. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Danny Brown is incapable of being a musician. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Tijuana is the largest city in Mexico. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Bruce Shand was awarded the Military Cross. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Kleshas are mental games. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Finding Dory was spearheaded by Angus MacLane. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Kenneth Lonergan date of birth is October 16, 1962. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Creedence Clearwater Revival did not have John Fogerty as lead vocalist and guitarist. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Palo Alto, California is a greenhouse gas contributor. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Chile is a nation. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Albert S. Ruddy is born in China. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Tremont Street Subway was designed by Japanese engineers. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim John McEnroe and Tatum O'Neal had 3 kids together. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Nicholas Brody only appears on basic cable. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Palo Alto, California does trade with Santa Clara County. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Justine Bateman is a writer. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Rupert Murdoch lacks control of 21st Century Fox. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Nicholas Brody created and produces Homeland. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Amyotrophic lateral sclerosis is a disease that usually starts around the age of 60. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The 100 does not involve a space habitat called The Ark. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The only film ever created in 1997 was Soul Food. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Capsicum chinense is a species of chili pepper. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Albert S. Ruddy is born on Mars. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Numb (Linkin Park song) was the most played song in Rock Band 3. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Osamu Tezuka has a mother. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Marcus Bentley finished college on October 4th, 1967. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Varsity Blues (film) was re-filmed with a $16 million budget. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Jenna Jameson worked as a stripper. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Mike Huckabee was Governor of Kansas. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Morse Code is a way of communicating. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Atlanta, Georgia is a place where Due Date was shot. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Colombiana was only produced by George Lucas. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Sora (Kingdom Hearts) searches for his enemies in the world of Kingdom Hearts. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The horse was domesticated on a broad scale by 3000 BC. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Eva Green made her film debut in a 2001 film directed by Bernardo Bertolucci. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Leonard Nimoy was in the video game Civilization IV. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Annette Badland played Doomsday Dora in The Sparticle Mystery. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Quran is Buddhist. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Bradley Fuller was arrested with Andrew Form. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim During 1927 - 1941 Mount Rushmore was created. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Roar (song) is a Katy Perry song from her fifth album. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Soyuz was part of the Soviet army. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tool has performed tours. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Middle-earth was created by J. K. Rowling. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Paris (Paris Hilton album) incorporates rhythm and lyrics of soul. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Tilda Swinton does performance art. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Stanley Williams died in 2007. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Taylor Lautner appeared in Malcolm in the Middle. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Stan Beeman is in The Americans. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Chagatai language was the shared literary language of Central Asia until the 19th century. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Tijuana is in NAFTA. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Soyuz was part of the Soviet space program. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Blue Jasmine has Sally Hawkins directing it. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Melancholia stars a Polish-Canadian lion. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Raees (film) prominently features an Indian movie actor who was born in 1965. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Carlos Santana is a comedian. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Savages was an American children's film. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Richard Dawkins makes regular internet appearances. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Edmund H. North was British. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim The Closer's sixth season was TNT's highest rated drama. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Motion is good for heart health. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Despicable Me 2 was written by a lake. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Damon Albarn's debut album was co-recorded by Richard Russell. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Chris Renaud directed Despicable Me 2. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The NAACP Image Award for Outstanding Supporting Actor in a Drama Series has been rejected by Omar Epps. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim John Deighton was forced to pursue other lines of work outside of tending his bar. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Colin Kaepernick is a football player. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Byron Howard co-directed the television show Tangled. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Brad Wilk started his career as a clown. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Miracle at St. Anna is set during a war. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim The Sterile Cuckoo was directed by Tim Burton. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Miracle at St. Anna is set during the War of the Roses. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim St. Anger is the eighth studio album by an American heavy metal band. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Rabbta (song) is a Hindi song from a 2016 Bollywood film. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Lou Gehrig got more votes than anyone else on America's Next Top Model in 1999. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Beach was released in 2000. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Croatia is lawless. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Birthday Song (2 Chainz song) features Drake. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim XHamster puts into production a reality series. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim A Milli is a song by a jazz recording artist. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Aristotle spent time in prison. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The Wallace is a literary work. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Winter's Tale was published in 1970. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Tilda Swinton is a vegan. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim The final season of Lost was watched by an average of 11 million viewers per episode. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Beaverton, Oregon's city center is ninety miles west of downtown Portland. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Global warming threatens traveling from the increase in floods. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Kenneth Lonergan is a writer of screenplays. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Michigan is the least populous of the 50 United States. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Aleister Crowley was a singer. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Edmund H. North was a screenwriter. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Angela Bassett started her film career in 1954. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Matteo Renzi is Jewish. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Penguin Books revolutionized publishing. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Sleipnir appears nowhere. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Tim McGraw was on vacation with Reese Witherspoon. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim Bhagat Singh was a revolutionary. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Stanley Williams was sentenced to life in prison. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim Recovery is a pop album. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------
#
# Appended claim AMGTV has sports television programming. with label SUPPORTS to the test set.
# -------------------------------------------------------------
#
# Appended claim Mogadishu is a village. with label REFUTES to the test set.
# -------------------------------------------------------------
#
# Appended claim No CEO of Lockheed Martin has been born between November and March. with label NOT ENOUGH INFO to the test set.
# -------------------------------------------------------------

# %%
print(test_sub_valid_sentEx_A['label'].value_counts())
print(test_sub_valid_sentEx_B['label'].value_counts())
print(test_sub_valid_sentEx_C['label'].value_counts())
# Out:
# label
# SUPPORTS           33
# REFUTES            33
# NOT ENOUGH INFO    33
# Name: count, dtype: int64
# label
# SUPPORTS           33
# REFUTES            33
# NOT ENOUGH INFO    33
# Name: count, dtype: int64
# label
# SUPPORTS           33
# REFUTES            33
# NOT ENOUGH INFO    33
# Name: count, dtype: int64

# %%
# Check for duplicates by id between all three dataframes
ab_overlap = len(set(test_sub_valid_sentEx_A['id']).intersection(set(test_sub_valid_sentEx_B['id'])))
ac_overlap = len(set(test_sub_valid_sentEx_A['id']).intersection(set(test_sub_valid_sentEx_C['id'])))
bc_overlap = len(set(test_sub_valid_sentEx_B['id']).intersection(set(test_sub_valid_sentEx_C['id'])))
print(f"Overlap between A and B: {ab_overlap}")
print(f"Overlap between A and C: {ac_overlap}")
print(f"Overlap between B and C: {bc_overlap}")
# Out:
# Overlap between A and B: 0
# Overlap between A and C: 0
# Overlap between B and C: 0

# %%
# !mkdir -p tabular_sets/tabular_sentEx_paper_dev_test

# %%
test_sub_valid_sentEx_A.to_csv('./tabular_sets/tabular_sentEx_paper_dev_test/test_sub_valid_sentEx_A.csv', index=False)
test_sub_valid_sentEx_B.to_csv('./tabular_sets/tabular_sentEx_paper_dev_test/test_sub_valid_sentEx_B.csv', index=False)
test_sub_valid_sentEx_C.to_csv('./tabular_sets/tabular_sentEx_paper_dev_test/test_sub_valid_sentEx_C.csv', index=False)
