# %%
import pandas as pd
import ast  # To safely evaluate the string representation of lists
import math
import os
import random
import nltk
import os
import sys
import datetime
import argparse
import json
import openai
from openai import OpenAI

from google.colab import drive, userdata
drive.mount('/content/drive')
# Adjust path as needed
BASE_DIR = '/content/drive/MyDrive/SUNY_Poly_DSA598/'
DATA_DIR = os.path.join(BASE_DIR, 'datasets/FEVER/')

# --- Download NLTK sentence tokenizer if needed ---
nltk.download('punkt')
nltk.download('punkt_tab')

# --- Set up OpenAI API key ---
api_key = userdata.get('openaikey')

client = OpenAI(api_key=api_key)
def create_ft_job(job_name, train_path, val_path):
    """
    Create a fine-tuning job using the OpenAI API.
    """
    # Upload the training file
    training_file = client.files.create(
        file=open(train_path, "rb"),
        purpose="fine-tune"    )

    # Upload the validation file
    validation_file = client.files.create(
        file=open(val_path, "rb"),
        purpose="fine-tune"    )

    # Create the fine-tuning job
    fine_tuning_job = client.fine_tuning.jobs.create(
        training_file=training_file.id,
        validation_file=validation_file.id,
        model="gpt-4o-2024-08-06",
        seed=2025,
        method={
          "type": "supervised",
          "supervised": {
            "hyperparameters": {
              "n_epochs": 4,
              "batch_size": 4
            }
          }
        }
    )
    return fine_tuning_job.id

def get_ft_job_list():
    """
    Get the list of fine-tuning jobs using the OpenAI API.
    """
    fine_tuning_jobs = client.fine_tuning.jobs.list()
    return fine_tuning_jobs

def get_ft_job_status(job_id):
    """
    Get the status of a specific fine-tuning job using the OpenAI API.
    """
    fine_tuning_job = client.fine_tuning.jobs.retrieve(job_id)
    return fine_tuning_job

def get_ft_job_results(job_id):
    """
    Get the results of a specific fine-tuning job using the OpenAI API.
    """
    fine_tuning_job = client.fine_tuning.jobs.retrieve(job_id)
    return fine_tuning_job
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
"""
{"messages": [{"role": "system", "content": ""}, {"role": "user", "content": "Extract sentences from the source text that are relevant (either supporting or refuting) to the preceding claim. Return a comma separated list of sentences.\n\nClaim: Fox 2000 Pictures released the film Soul Food.\n\nSource Text: Soul Food is a 1997 American comedy-drama film produced by Kenneth `` Babyface '' Edmonds , Tracey Edmonds and Robert Teitel and released by Fox 2000 Pictures . Featuring an ensemble cast , the film stars Vanessa L. Williams , Vivica A. Fox , Nia Long , Michael Beach , Mekhi Phifer , Jeffrey D. Sams , Irma P. Hall , Gina Ravera and Brandon Hammond . Written and directed by George Tillman , Jr. -- in his major studio debut -- the film centers on the trials of an extended African-American family , held together by longstanding family traditions which begin to fade as serious problems take center stage .   Tillman based the family in the film on his own and Soul Food was widely acclaimed for presenting a more positive image of African-Americans than is typically seen in Hollywood films . In 2000 , Showtime premiered a one-hour television series based upon the film . In 2015 , it was announced that 20th Century Fox is planning a sequel for film called More Soul Food , written by Tillman , Jr. . "}, {"role": "assistant", "content": "Soul Food is a 1997 American comedy-drama film produced by Kenneth `` Babyface '' Edmonds , Tracey Edmonds and Robert Teitel and released by Fox 2000 Pictures ."}]}
"""
train_data = pd.read_csv(os.path.join(BASE_DIR, "datasets/FEVER/tabular_sets/tabular_sentEx_paper_dev_train/v1_segmented_sentIDs_n3461_04-04_002.csv"))
valid_data = pd.read_csv(os.path.join(BASE_DIR, "datasets/FEVER/tabular_sets/tabular_sentEx_paper_dev_valid/v1_segmented_sentIDs_n1482_04-04_002.csv"))
# Format dataset for chat-based fine-tuning for page title prediction.
def prepare_chat_finetuning_data(df):
    formatted_data = []
    supports = 0
    refutes = 0
    nei = 0

    bracket_mapping = {
        "-LRB-": "(",
        "-RRB-": ")",
        "-LSB-": "[",
        "-RSB-": "]",
        "-LCB-": "{",
        "-RCB-": "}"
    }

    for _, row in df.iterrows():
      print(f"On row {row['id']}")
      print(f"Label: {row['label']}")

      page_titles = []
      claim = row['claim']
      print(row['evidence_items'])
      #print(claim)
      if row['label'] == 'NOT ENOUGH INFO': # We don't need NEI (negative) samples for page title relationship modeling
          continue
      elif row['label'] == 'SUPPORTS':
          evidence_items = row['evidence_items']
          evidence_items = ast.literal_eval(evidence_items)
          print(evidence_items)
          if supports < 100:
            for item in evidence_items: # item is a list, we want the second element (the page title)
                mapped_text = item[1]
                for key, value in bracket_mapping.items():
                    mapped_text = mapped_text.replace(key, value)
                page_titles.append(f"'{mapped_text}'")

            # Drop duplicate page titles (we only need GPT_query to suggest the page, not necessarily how many sentences were extracted from that page, which is what the repeated page titles indicate).
            page_titles = list(set(page_titles))

            formatted_data.append({
                "messages": [
                    {"role": "system", "content": "You are an assistant that identifies relevant Wikipedia page titles based on a claim."},
                    {"role": "user", "content": f"Given the claim '{claim}', list the most relevant Wikipedia page titles likely to contain evidence. Consider key facts about the claim, such as the type of items mentioned. Respond with only a bracketed list of lowercase page titles with spaces as underscores, each title wrapped in single quotes and separated by a comma."},
                    {"role": "assistant", "content": f'[{",".join(page_titles)}]'},
                ]
            })
            supports += 1
          else:
            continue
      elif row['label'] == 'REFUTES':
          evidence_items = row['evidence_items']
          evidence_items = ast.literal_eval(evidence_items)
          print(evidence_items)
          if refutes < 100:
            for item in evidence_items: # item
                mapped_text = item[1]
                for key, value in bracket_mapping.items():
                    mapped_text = mapped_text.replace(key, value)
                page_titles.append(f"'{mapped_text}'")

            # Drop duplicate page titles (we only need GPT_query to suggest the page, not necessarily how many sentences were extracted from that page, which is what the repeated page titles indicate).
            page_titles = list(set(page_titles))

            formatted_data.append({
                "messages": [
                    {"role": "system", "content": "You are an assistant that identifies relevant Wikipedia page titles based on a claim."},
                    {"role": "user", "content": f"Given the claim '{claim}', list the most relevant Wikipedia page titles likely to contain evidence. Consider key facts about the claim, such as the type of items mentioned. Respond with only a bracketed list of lowercase page titles with spaces as underscores, each title wrapped in single quotes and separated by a comma."},
                    {"role": "assistant", "content": f'[{",".join(page_titles)}]'},
                ]
            })
            refutes += 1
          else:
            continue
      else:
          raise ValueError(f"Unknown label: {row['label']}")
      if supports >= 100 and refutes >= 100:
          print(f"Reached 100 supports and refutes. Stopping.")
          break

    # Shuffle the data
    random.shuffle(formatted_data)
    return formatted_data


# Save the data in JSONL format
def jsonize(data, filename):
    with open(filename, 'w') as f:
        for line in data:
            f.write(json.dumps(line) + '\n')

# Prepare the training and validation data
# Shuffle the dataframes with a seed (2025)
train_data = train_data.sample(frac=1, random_state=2025).reset_index(drop=True)
valid_data = valid_data.sample(frac=1, random_state=2025).reset_index(drop=True)

# Prepare the training data
train_data = prepare_chat_finetuning_data(train_data)
valid_data = prepare_chat_finetuning_data(valid_data)

TRAIN_SAVE_DIR = os.path.join(DATA_DIR, 'GPT_sets/GPT_query_paper_dev_train/')
VALID_SAVE_DIR = os.path.join(DATA_DIR, 'GPT_sets/GPT_query_paper_dev_valid/')

train_filename = os.path.join(TRAIN_SAVE_DIR, 'prompt_v1_segmented_n200_balanced_04-27_002.jsonl')
valid_filename = os.path.join(VALID_SAVE_DIR, 'prompt_v1_segmented_n200_balanced_04-27_002.jsonl')

# Save the training and validation data
jsonize(train_data, train_filename)
jsonize(valid_data, valid_filename)
# Out:
# On row 1751
# Label: REFUTES
# [["For its output , it might pass the message through unchanged for delivery to the user 's mailbox , redirect the message for delivery elsewhere , or even throw the message away .", 'Email_filtering', 5, []]]
# [["For its output , it might pass the message through unchanged for delivery to the user 's mailbox , redirect the message for delivery elsewhere , or even throw the message away .", 'Email_filtering', 5, []]]
# On row 708
# Label: REFUTES
# [["Winfield Scott `` Scotty '' Moore III -LRB- December 27 , 1931 -- June 28 , 2016 -RRB- was an American guitarist and recording engineer .", 'Scotty_Moore', 0, []]]
# [["Winfield Scott `` Scotty '' Moore III -LRB- December 27 , 1931 -- June 28 , 2016 -RRB- was an American guitarist and recording engineer .", 'Scotty_Moore', 0, []]]
# On row 2247
# Label: SUPPORTS
# [["Stanley `` Tookie '' Williams III -LRB- December 29 , 1953 -- December 13 , 2005 -RRB- was an American gang member and convicted murderer , who was part of the West Side Crips , a street gang which has its roots in South Central Los Angeles in 1969 .", 'Stanley_Williams', 0, ['street gang', 'South Central Los Angeles', 'Crips']]]
# [["Stanley `` Tookie '' Williams III -LRB- December 29 , 1953 -- December 13 , 2005 -RRB- was an American gang member and convicted murderer , who was part of the West Side Crips , a street gang which has its roots in South Central Los Angeles in 1969 .", 'Stanley_Williams', 0, ['street gang', 'South Central Los Angeles', 'Crips']]]
# On row 2309
# Label: NOT ENOUGH INFO
# He was clerk of the supreme court of Providence County in 1 and proprietor of a distillery in Cranston until 1824, when he became a cotton manufacturer in Providence, Pontiac, and Woonsocket.
# John Hopkins Clarke (April 1, 1 – November 23, 1870) was a United States senator from Rhode Island.
# He was a member of the Rhode Island House of Representatives from 1 to 1 and 1 to 1847.
# Born in Elizabeth, New Jersey, he moved to Providence, where he studied under a private teacher.
# He graduated from Brown University in 1809, studied law, was admitted to the bar and commenced practice in Providence in 1812.
# On row 1941
# Label: NOT ENOUGH INFO
# The band is also known for reuniting Anthrax members, guitarist Scott Ian and drummer Charlie Benante, with their former bassist Dan Lilker.1 Their instrumental song "March of the S.O.D."
# was an American crossover thrash band formed in New York City in 1985.1 They are credited as being amongst the first groups to fuse hardcore punk with thrash metal into a style often referred to as crossover thrash.
# from their 1 debut album, Speak English or Die, was the Headbangers Ball intro anthem for many years.
# Stormtroopers of Death (abbreviated to S.O.D.)
# Another song from the same album, "Chromatic Death", was also used during the show as a segue between ads and videos.
# On row 425
# Label: SUPPORTS
# [['Carlos Santana -LRB- born July 20 , 1947 -RRB- is a Mexican and American musician who first became famous in the late 1960s and early 1970s with his band , Santana , which pioneered a fusion of rock and Latin American music .', 'Carlos_Santana', 0, ['Santana (band)', 'Santana']]]
# [['Carlos Santana -LRB- born July 20 , 1947 -RRB- is a Mexican and American musician who first became famous in the late 1960s and early 1970s with his band , Santana , which pioneered a fusion of rock and Latin American music .', 'Carlos_Santana', 0, ['Santana (band)', 'Santana']]]
# On row 865
# Label: NOT ENOUGH INFO
# Kyokutaisei Takuya (Japanese: 旭大星 託也, born 1 October 1 as Takuya Ōgushi (大串 拓也, Ōgushi Takuya)) is a Japanese former professional sumo wrestler from Asahikawa, Hokkaido.
# His highest rank has been maegashira 8.
# His debut in maezumō was in January 2008, and his first makuuchi division honbasho was the Natsu tournament in May 2018.
# He has one special prize for Fighting Spirit.
# He was a member of Ōshima stable and retired in December 2024.
# On row 3311
# Label: REFUTES
# [['Stan Beeman is a fictional character in the American television drama series The Americans on FX , and the supporting male character .', 'Stan_Beeman', 0, ['FX', 'The Americans', 'fictional character', 'The Americans (2013 TV series)', 'FX (TV channel)']]]
# [['Stan Beeman is a fictional character in the American television drama series The Americans on FX , and the supporting male character .', 'Stan_Beeman', 0, ['FX', 'The Americans', 'fictional character', 'The Americans (2013 TV series)', 'FX (TV channel)']]]
# On row 1656
# Label: NOT ENOUGH INFO
# He also earned a bronze medal at the 2 Francophone Games and a silver at the 2 Francophone Games.
# He represented Canada in the sport of Judo at the 2 Summer 2 Summer Olympics and at five World Championships.
# Nicholas was a member of Canada's National Team for more than ten years and won many medals domestically and internationally including 1 medals on the Grand Slam, Grand Prix and World Cup circuit including back to back bronze medals at the prestigious Tokyo Grand Slam as well as the bronze medal in the men's lightweight division ( 73kg) at the 2 Pan American Games, alongside Cuba's Ronald Girones and another bronze at the 2 Pan American Games in Mexico.
# Nicholas "Nick" Tritton (born 2 July 1 in Guelph, Ontario) is a male judoka who grew up in the Perth/Lanark area of Ontario Canada.
# He won 5 medals at the Pan American Judo Championships (bronze in 2007, 2 2011, silver in 2 and gold in 2 - missed 2 due to injury).
# On row 1748
# Label: REFUTES
# [['Billie Joe Armstrong -LRB- born February 17 , 1972 -RRB- is an American musician , singer , songwriter and actor who is best known as the lead vocalist , primary songwriter , and guitarist of the punk rock band Green Day , which he co-founded with Mike Dirnt .', 'Billie_Joe_Armstrong', 0, ['Green Day', 'Mike Dirnt', 'punk rock']]]
# [['Billie Joe Armstrong -LRB- born February 17 , 1972 -RRB- is an American musician , singer , songwriter and actor who is best known as the lead vocalist , primary songwriter , and guitarist of the punk rock band Green Day , which he co-founded with Mike Dirnt .', 'Billie_Joe_Armstrong', 0, ['Green Day', 'Mike Dirnt', 'punk rock']]]
# On row 3133
# Label: SUPPORTS
# [['In 2013 she was ranked as the second highest earning actress/models in Israel , behind Bar Refaeli , but ahead of Esti Ginzburg and Shlomit Malka , with the majority of her income coming from acting .', 'Gal_Gadot', 4, ['Shlomit Malka', 'Israel', 'Esti Ginzburg', 'Bar Refaeli']]]
# [['In 2013 she was ranked as the second highest earning actress/models in Israel , behind Bar Refaeli , but ahead of Esti Ginzburg and Shlomit Malka , with the majority of her income coming from acting .', 'Gal_Gadot', 4, ['Shlomit Malka', 'Israel', 'Esti Ginzburg', 'Bar Refaeli']]]
# On row 1566
# Label: NOT ENOUGH INFO
# The system subsequently rapidly weakened and became an extratropical cyclone during December 1, before they were absorbed by an advancing trough of low pressure near 50°S on December 4.
# Over the next couple of days the system intensified further and developed an eye feature as it erratically moved towards Fiji.
# Over the next three days the system moved towards the west-northwest, before it was named Sina during November 24, after it had developed into a tropical cyclone.
# Severe Tropical Cyclone Sina was the only named tropical cyclone to develop within the South Pacific basin during the 1990– season.
# The system was first noted as a shallow depression within the South Pacific Convergence Zone to the west of Wallis Island.
# On row 2374
# Label: REFUTES
# [['Poseidon grossed $ 181,674,817 at the worldwide box office on a budget of $ 160 million .', 'Poseidon_-LRB-film-RRB-', 6, ['box office']]]
# [['Poseidon grossed $ 181,674,817 at the worldwide box office on a budget of $ 160 million .', 'Poseidon_-LRB-film-RRB-', 6, ['box office']]]
# On row 2435
# Label: NOT ENOUGH INFO
# Latrobe starting quarterback, Eddie Blair, due to a scheduling conflict could not play in the game.
# This led Latrobe manager, Dave Berry to hire Brallier to play against Jeannette for $10, plus expenses.
# Latrobe would go on to win that game 12-0.23
# This event occurred in 1895, a few days before Latrobe's game against Jeannette.
# The Jeannette Athletic Club, also referred to as the Jeannette Indians, was an early football team, based in Jeannette, Pennsylvania from 1 until around 1906.1 The team is best known for its role in the Latrobe Athletic Association's hiring of John Brallier, who became the first player to openly turn professional.
# On row 2212
# Label: REFUTES
# [['Cheese in the Trap is a South Korean television series starring Park Hae-jin , Kim Go-eun , Seo Kang-joon and Lee Sung-kyung .', 'Cheese_in_the_Trap_-LRB-TV_series-RRB-', 0, ['Park Hae-jin', 'Lee Sung-kyung', 'South Korean television series', 'Kim Go-eun', 'Cheese in the Trap', 'Korean drama', 'Seo Kang-joon']]]
# [['Cheese in the Trap is a South Korean television series starring Park Hae-jin , Kim Go-eun , Seo Kang-joon and Lee Sung-kyung .', 'Cheese_in_the_Trap_-LRB-TV_series-RRB-', 0, ['Park Hae-jin', 'Lee Sung-kyung', 'South Korean television series', 'Kim Go-eun', 'Cheese in the Trap', 'Korean drama', 'Seo Kang-joon']]]
# On row 1227
# Label: REFUTES
# [['Angela Evelyn Bassett -LRB- born August 16 , 1958 -RRB- is an American actress .', 'Angela_Bassett', 0, []]]
# [['Angela Evelyn Bassett -LRB- born August 16 , 1958 -RRB- is an American actress .', 'Angela_Bassett', 0, []]]
# On row 3316
# Label: SUPPORTS
# [['Marnie is a 1964 American psychological thriller film directed by Alfred Hitchcock .', 'Marnie_-LRB-film-RRB-', 0, ['psychological thriller film', 'Marnie', 'Alfred Hitchcock', 'psychological thriller']]]
# [['Marnie is a 1964 American psychological thriller film directed by Alfred Hitchcock .', 'Marnie_-LRB-film-RRB-', 0, ['psychological thriller film', 'Marnie', 'Alfred Hitchcock', 'psychological thriller']]]
# On row 1615
# Label: SUPPORTS
# [["Introduced in 1996 's A Game of Thrones , Sam is the eldest son of Randyll Tarly , from the fictional kingdom of Westeros .", 'Samwell_Tarly', 3, ['Randyll Tarly', 'Game of Thrones', 'A Game of Thrones', 'Westeros']], ['A Game of Thrones is the first novel in A Song of Ice and Fire , a series of fantasy novels by American author George R. R. Martin .', 'A_Game_of_Thrones', 0, ['fantasy', 'Game of Thrones', 'George R. R. Martin', 'A Song of Ice and Fire']], ['Samwell Tarly , called Sam , is a fictional character in the A Song of Ice and Fire series of fantasy novels by American author George R. R. Martin , and its television adaptation Game of Thrones .', 'Samwell_Tarly', 0, ['fantasy', 'Game of Thrones', 'fictional character', 'George R. R. Martin', 'A Song of Ice and Fire']], ["He subsequently appeared in Martin 's A Clash of Kings before being a POV character in the later novels .", 'Samwell_Tarly', 4, ['A Clash of Kings']], ['A Clash of Kings is the second novel in A Song of Ice and Fire , an epic fantasy series by American author George R. R. Martin expected to consist of seven volumes .', 'A_Clash_of_Kings', 0, ['George R. R. Martin', 'A Song of Ice and Fire', 'epic fantasy']]]
# [["Introduced in 1996 's A Game of Thrones , Sam is the eldest son of Randyll Tarly , from the fictional kingdom of Westeros .", 'Samwell_Tarly', 3, ['Randyll Tarly', 'Game of Thrones', 'A Game of Thrones', 'Westeros']], ['A Game of Thrones is the first novel in A Song of Ice and Fire , a series of fantasy novels by American author George R. R. Martin .', 'A_Game_of_Thrones', 0, ['fantasy', 'Game of Thrones', 'George R. R. Martin', 'A Song of Ice and Fire']], ['Samwell Tarly , called Sam , is a fictional character in the A Song of Ice and Fire series of fantasy novels by American author George R. R. Martin , and its television adaptation Game of Thrones .', 'Samwell_Tarly', 0, ['fantasy', 'Game of Thrones', 'fictional character', 'George R. R. Martin', 'A Song of Ice and Fire']], ["He subsequently appeared in Martin 's A Clash of Kings before being a POV character in the later novels .", 'Samwell_Tarly', 4, ['A Clash of Kings']], ['A Clash of Kings is the second novel in A Song of Ice and Fire , an epic fantasy series by American author George R. R. Martin expected to consist of seven volumes .', 'A_Clash_of_Kings', 0, ['George R. R. Martin', 'A Song of Ice and Fire', 'epic fantasy']]]
# On row 1011
# Label: REFUTES
# [['Fabian Nicieza -LRB- born 31 December 1961 -RRB- is an Argentine-American comic book writer and editor who is best known for his work on Marvel titles such as X-Men , X-Force , New Warriors , Cable and Deadpool , and Thunderbolts , for all of which he helped create numerous characters .', 'Fabian_Nicieza', 0, ['X-Force', 'Cable and Deadpool', 'editor', 'X-Men', 'New Warriors', 'Thunderbolts (comics)', 'Deadpool', 'Thunderbolts', 'editing']]]
# [['Fabian Nicieza -LRB- born 31 December 1961 -RRB- is an Argentine-American comic book writer and editor who is best known for his work on Marvel titles such as X-Men , X-Force , New Warriors , Cable and Deadpool , and Thunderbolts , for all of which he helped create numerous characters .', 'Fabian_Nicieza', 0, ['X-Force', 'Cable and Deadpool', 'editor', 'X-Men', 'New Warriors', 'Thunderbolts (comics)', 'Deadpool', 'Thunderbolts', 'editing']]]
# On row 1935
# Label: NOT ENOUGH INFO
# She has said she is working on a novel called 'The Murder of the Real and has reportedly resumed writing poetry.citation needed
# Her third book of poetry, The Book of Coming and Going Forth by Day was pulled from circulation by the author, as she refused to write or publish poetry for three years for political reasons, only then publishing one poem in a magazine out of Singapore, and submitting 3 to the Canadian Robin Blaser Award.
# She is the recipient of a 2 Gertrude Stein Award and was 1st Runner-Up for the Robin Blaser Award in 2015.
# Her poetry was part of the Bunker Poetico installation and anthology for the 49th Venice Bienalle.1 Her second tract, Loquela, was published in 2 by Insert Blanc Press.
# Allyssa Wolf (born 1971) is an American poet.
# On row 1452
# Label: NOT ENOUGH INFO
# The northern terminus is at PA 1 in Tunkhannock Township.
# Between 2 and 2015, an E-ZPass-only interchange was constructed with I-476.
# Pennsylvania Route 9 (PA 903) is a 17.7-mile-long (28.5km) state highway located in Carbon and Monroe counties in Pennsylvania.
# The southern terminus is at U.S. Route 2 (US 209) in Jim Thorpe.
# The highway was fully paved in the 1930s.
# On row 1170
# Label: REFUTES
# [['The Sugarland Express is a 1974 American crime drama film co-written and directed by Steven Spielberg in his theatrical feature film directorial debut .', 'The_Sugarland_Express', 3, ['List of directorial debuts', 'crime', 'crime film', 'theatrical feature film directorial debut', 'Steven Spielberg', 'drama film']]]
# [['The Sugarland Express is a 1974 American crime drama film co-written and directed by Steven Spielberg in his theatrical feature film directorial debut .', 'The_Sugarland_Express', 3, ['List of directorial debuts', 'crime', 'crime film', 'theatrical feature film directorial debut', 'Steven Spielberg', 'drama film']]]
# On row 3186
# Label: NOT ENOUGH INFO
# In 1 he enrolled at Illinois State University, where he received both a BA and MA.
# He served in Korea during 1953.
# He was released in 1963, and returned to Peoria.
# After leaving the Marines he moved to California and eventually had a son with his then-wife Luana.
# He taught at the university up until his death on May 2, 1974.
# On row 3422
# Label: REFUTES
# [['Rachel Karen Green is a fictional character , one of the six main characters who appeared in the American sitcom Friends .', 'Rachel_Green', 0, ['six main characters', 'Friends', 'List of Friends characters']]]
# [['Rachel Karen Green is a fictional character , one of the six main characters who appeared in the American sitcom Friends .', 'Rachel_Green', 0, ['six main characters', 'Friends', 'List of Friends characters']]]
# On row 2231
# Label: NOT ENOUGH INFO
# Its southwestern boundary intersects the border of Ningbo, also entirely at sea.
# The district boundary meets that of Daishan County out at sea to the north of the island.
# It is based on the larger northwestern half of Zhoushan Island, where it borders Putuo in the east.
# The total area is 1,4 square kilometres.
# Dinghai ⓘ (simplified Chinese 定海区; traditional Chinese 定海區; pinyin Dìnghǎi Qū) is a district of Zhoushan City made of 1 islands in Zhejiang province, China.
# On row 419
# Label: SUPPORTS
# [['She is the youngest daughter of Billy Ray Cyrus and younger sister of Miley Cyrus and Trace Cyrus .', 'Noah_Cyrus', 4, ['Trace Cyrus', 'Miley Cyrus', 'Billy Ray Cyrus']]]
# [['She is the youngest daughter of Billy Ray Cyrus and younger sister of Miley Cyrus and Trace Cyrus .', 'Noah_Cyrus', 4, ['Trace Cyrus', 'Miley Cyrus', 'Billy Ray Cyrus']]]
# On row 548
# Label: SUPPORTS
# [['Tool is an American rock band from Los Angeles , California .', 'Tool_-LRB-band-RRB-', 0, ['Los Angeles', 'rock', 'rock music']]]
# [['Tool is an American rock band from Los Angeles , California .', 'Tool_-LRB-band-RRB-', 0, ['Los Angeles', 'rock', 'rock music']]]
# On row 684
# Label: REFUTES
# [['Johanna Mansfield Sullivan Macy -LRB- April 14 , 1866 -- October 20 , 1936 -RRB- , better known as Anne Sullivan , was an American teacher , best known for being the instructor and lifelong companion of Helen Keller .', 'Anne_Sullivan', 0, ['Helen Keller']]]
# [['Johanna Mansfield Sullivan Macy -LRB- April 14 , 1866 -- October 20 , 1936 -RRB- , better known as Anne Sullivan , was an American teacher , best known for being the instructor and lifelong companion of Helen Keller .', 'Anne_Sullivan', 0, ['Helen Keller']]]
# On row 1471
# Label: SUPPORTS
# [['Chile , is a South American country occupying a long , narrow strip of land between the Andes to the east and the Pacific Ocean to the west .', 'Chile', 0, ['Andes']]]
# [['Chile , is a South American country occupying a long , narrow strip of land between the Andes to the east and the Pacific Ocean to the west .', 'Chile', 0, ['Andes']]]
# On row 1846
# Label: SUPPORTS
# [['Daag : A Poem of Love is a 1973 Bollywood drama film produced and directed by Yash Chopra in his debut as a producer , which laid the foundation of Yash Raj Films .', 'Daag_-LRB-1973_film-RRB-', 0, ['Yash Chopra', 'Yash Raj Films', 'Bollywood', 'drama film', 'Drama Film']], ['Rajesh Khanna impressed the audience and critics with his performance and the film was a superhit .', 'Daag_-LRB-1973_film-RRB-', 2, ['Rajesh Khanna']], ["The film was made at the height of the Rajesh Khanna craze and became a `` super hit '' at the box office .", 'Daag_-LRB-1973_film-RRB-', 8, ['Rajesh Khanna']]]
# [['Daag : A Poem of Love is a 1973 Bollywood drama film produced and directed by Yash Chopra in his debut as a producer , which laid the foundation of Yash Raj Films .', 'Daag_-LRB-1973_film-RRB-', 0, ['Yash Chopra', 'Yash Raj Films', 'Bollywood', 'drama film', 'Drama Film']], ['Rajesh Khanna impressed the audience and critics with his performance and the film was a superhit .', 'Daag_-LRB-1973_film-RRB-', 2, ['Rajesh Khanna']], ["The film was made at the height of the Rajesh Khanna craze and became a `` super hit '' at the box office .", 'Daag_-LRB-1973_film-RRB-', 8, ['Rajesh Khanna']]]
# On row 950
# Label: SUPPORTS
# [['David has 20 UK top 40 singles , and seven UK top 40 albums , selling over 15 million records worldwide as a solo artist .', 'Craig_David', 2, []], ['David has been nominated for thirteen Brit Awards : four times for Best British Male , and twice received a Grammy Award nomination for Best Male Pop Vocal Performance .', 'Craig_David', 5, ['Best Male Pop Vocal Performance', 'Grammy Award', 'Grammy Award for Best Male Pop Vocal Performance', 'Brit Awards']], ["Craig Ashley David -LRB- born 5 May 1981 -RRB- is a British singer , songwriter , rapper and record producer who rose to fame in 1999 , featuring on the single , `` Re-Rewind '' by Artful Dodger .", 'Craig_David', 0, ['Artful Dodger', 'Re-Rewind', 'Artful Dodger (UK band)', 'Re-Rewind (The Crowd Say Bo Selecta)']]]
# [['David has 20 UK top 40 singles , and seven UK top 40 albums , selling over 15 million records worldwide as a solo artist .', 'Craig_David', 2, []], ['David has been nominated for thirteen Brit Awards : four times for Best British Male , and twice received a Grammy Award nomination for Best Male Pop Vocal Performance .', 'Craig_David', 5, ['Best Male Pop Vocal Performance', 'Grammy Award', 'Grammy Award for Best Male Pop Vocal Performance', 'Brit Awards']], ["Craig Ashley David -LRB- born 5 May 1981 -RRB- is a British singer , songwriter , rapper and record producer who rose to fame in 1999 , featuring on the single , `` Re-Rewind '' by Artful Dodger .", 'Craig_David', 0, ['Artful Dodger', 'Re-Rewind', 'Artful Dodger (UK band)', 'Re-Rewind (The Crowd Say Bo Selecta)']]]
# On row 846
# Label: REFUTES
# [['A floppy disk , also called a floppy , diskette or just disk , is a type of disk storage composed of a disk of thin and flexible magnetic storage medium , sealed in a rectangular plastic enclosure lined with fabric that removes dust particles .', 'Floppy_disk', 0, ['magnetic storage', 'disk storage']]]
# [['A floppy disk , also called a floppy , diskette or just disk , is a type of disk storage composed of a disk of thin and flexible magnetic storage medium , sealed in a rectangular plastic enclosure lined with fabric that removes dust particles .', 'Floppy_disk', 0, ['magnetic storage', 'disk storage']]]
# On row 3187
# Label: SUPPORTS
# [['Wish Upon is a 2017 supernatural horror thriller film directed by John R. Leonetti and starring Joey King , Ryan Phillipe , Ki Hong Lee , Shannon Purser , Sydney Park and Sherilyn Fenn .', 'Wish_Upon', 0, ['Ki Hong Lee', 'Sherilyn Fenn', 'thriller film', 'supernatural horror film', 'Sydney Park', 'John R. Leonetti', 'Shannon Purser', 'supernatural horror', 'Sydney Park (actress)', 'Ryan Phillipe', 'Joey King']]]
# [['Wish Upon is a 2017 supernatural horror thriller film directed by John R. Leonetti and starring Joey King , Ryan Phillipe , Ki Hong Lee , Shannon Purser , Sydney Park and Sherilyn Fenn .', 'Wish_Upon', 0, ['Ki Hong Lee', 'Sherilyn Fenn', 'thriller film', 'supernatural horror film', 'Sydney Park', 'John R. Leonetti', 'Shannon Purser', 'supernatural horror', 'Sydney Park (actress)', 'Ryan Phillipe', 'Joey King']]]
# On row 1575
# Label: NOT ENOUGH INFO
# Wilson retired as head of LAC in April 2009.
# Appointed in 2004, he had previously (as of July 1999) been National Archivist of Canada.
# In addition, he has published extensively on history, archives, heritage, and information management and has lectured both nationally and abroad.
# Ian E. Wilson OC (born April 1943) is a former chief Librarian and Archivist of Canada.
# His distinguished career has included archival and information management, university teaching and government service.
# On row 3052
# Label: SUPPORTS
# [['In the immediate vicinity of Naples are numerous culturally and historically significant sites , including the Palace of Caserta and the Roman ruins of Pompeii and Herculaneum .', 'Naples', 34, ['Herculaneum', 'Palace of Caserta', 'Pompeii']]]
# [['In the immediate vicinity of Naples are numerous culturally and historically significant sites , including the Palace of Caserta and the Roman ruins of Pompeii and Herculaneum .', 'Naples', 34, ['Herculaneum', 'Palace of Caserta', 'Pompeii']]]
# On row 3312
# Label: NOT ENOUGH INFO
# In 2014, the country ranked 43rd-largest coffee producer in the world.
# Still, it was not successful until the British began large-scale commercial production following the Colebrooke–Cameron Commission reforms of 1833.
# Coffee production in Sri Lanka peaked in 1870, with over 111,4 hectares (275,0 acres) being cultivated.
# Although coffee production remains a source of revenue, it is no longer a main economic sector.
# By 1860, the country was amongst the major coffee-producing nations in the world.
# On row 3240
# Label: NOT ENOUGH INFO
# Although erosion by the nearby stream has the potential of damaging the mound, it appears to be virtually undisturbed by human exploration.
# It is believed to have been built by people of the Adena culture, who constructed many burial mounds and other ceremonial earthworks in prehistoric Ohio.
# Because of its pristine state, the Horn Mound is a likely archaeological site,3 and for this reason it was listed on the National Register of Historic Places in 1974.1
# Located near the village of Tarlton,1 the mound sits along a stream at a significant distance from any other prehistoric sites.
# The Horn Mound is a Native American mound in eastern Pickaway County, Ohio, United States.
# On row 2972
# Label: REFUTES
# [["Thomas Jacob `` Jack '' Black -LRB- born August 28 , 1969 -RRB- is an American actor , comedian , writer , producer , musician and singer .", 'Jack_Black', 0, []], ['Tenacious D is an American comedy rock duo that was formed in Los Angeles , California in 1994 .', 'Tenacious_D', 0, ['California', 'Tenacious D (album)', 'Tenacious D', 'double act', 'American', 'duo', 'Los Angeles', 'United States', 'comedy rock']], ['Kyle Richard Gass -LRB- born July 14 , 1960 -RRB- , also known as KG , is an American singer-songwriter and actor .', 'Kyle_Gass', 0, []], ['Composed of lead vocalist and guitarist Jack Black and lead guitarist and vocalist Kyle Gass , the band has released three albums -- Tenacious D -LRB- 2001 -RRB- , The Pick of Destiny -LRB- 2006 -RRB- and Rize of the Fenix -LRB- 2012 -RRB- .', 'Tenacious_D', 1, ['Jack Black', 'Tenacious D (album)', 'The Pick of Destiny', 'Tenacious D', 'Rize of the Fenix', 'Kyle Gass']]]
# [["Thomas Jacob `` Jack '' Black -LRB- born August 28 , 1969 -RRB- is an American actor , comedian , writer , producer , musician and singer .", 'Jack_Black', 0, []], ['Tenacious D is an American comedy rock duo that was formed in Los Angeles , California in 1994 .', 'Tenacious_D', 0, ['California', 'Tenacious D (album)', 'Tenacious D', 'double act', 'American', 'duo', 'Los Angeles', 'United States', 'comedy rock']], ['Kyle Richard Gass -LRB- born July 14 , 1960 -RRB- , also known as KG , is an American singer-songwriter and actor .', 'Kyle_Gass', 0, []], ['Composed of lead vocalist and guitarist Jack Black and lead guitarist and vocalist Kyle Gass , the band has released three albums -- Tenacious D -LRB- 2001 -RRB- , The Pick of Destiny -LRB- 2006 -RRB- and Rize of the Fenix -LRB- 2012 -RRB- .', 'Tenacious_D', 1, ['Jack Black', 'Tenacious D (album)', 'The Pick of Destiny', 'Tenacious D', 'Rize of the Fenix', 'Kyle Gass']]]
# On row 2779
# Label: SUPPORTS
# [['He has also directed a film -- Hindustan Ki Kasam -LRB- 1999 -RRB- .', 'Veeru_Devgan', 3, ['Hindustan Ki Kasam (1999 film)', 'Hindustan Ki Kasam']], ['Hindustan Ki Kasam -LRB- English : Swear on India -RRB- is a 1999 Indian action film directed by Veeru Devgan and starring his son Ajay Devgan -LRB- in a dual role -RRB- , Amitabh Bachchan , Manisha Koirala and Sushmita Sen. The film was an average grosser , despite taking a bumper opening .', 'Hindustan_Ki_Kasam_-LRB-1999_film-RRB-', 0, ['Manisha Koirala', 'India', 'Amitabh Bachchan', 'Veeru Devgan', 'action film', 'Ajay Devgan', 'Sushmita Sen']], ['Veeru Devgan is an Indian stunt and action choreographer and film director in Bollywood .', 'Veeru_Devgan', 0, ['Bollywood']]]
# [['He has also directed a film -- Hindustan Ki Kasam -LRB- 1999 -RRB- .', 'Veeru_Devgan', 3, ['Hindustan Ki Kasam (1999 film)', 'Hindustan Ki Kasam']], ['Hindustan Ki Kasam -LRB- English : Swear on India -RRB- is a 1999 Indian action film directed by Veeru Devgan and starring his son Ajay Devgan -LRB- in a dual role -RRB- , Amitabh Bachchan , Manisha Koirala and Sushmita Sen. The film was an average grosser , despite taking a bumper opening .', 'Hindustan_Ki_Kasam_-LRB-1999_film-RRB-', 0, ['Manisha Koirala', 'India', 'Amitabh Bachchan', 'Veeru Devgan', 'action film', 'Ajay Devgan', 'Sushmita Sen']], ['Veeru Devgan is an Indian stunt and action choreographer and film director in Bollywood .', 'Veeru_Devgan', 0, ['Bollywood']]]
# On row 2472
# Label: SUPPORTS
# [["It has been covered by Pink , Crystal Kay , and Girls ' Generation and has also been performed on Glee , The X-Factor , and Britain 's Got Talent .", 'Rhythm_Nation', 23, ['Glee', 'Crystal Kay', 'The X-Factor', 'Glee (TV series)', 'Pink (singer)', 'Pink']]]
# [["It has been covered by Pink , Crystal Kay , and Girls ' Generation and has also been performed on Glee , The X-Factor , and Britain 's Got Talent .", 'Rhythm_Nation', 23, ['Glee', 'Crystal Kay', 'The X-Factor', 'Glee (TV series)', 'Pink (singer)', 'Pink']]]
# On row 1326
# Label: REFUTES
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# On row 897
# Label: REFUTES
# [['Produced by Illumination Entertainment for Universal Pictures , and animated by Illumination Mac Guff , the film is directed by Pierre Coffin and Chris Renaud , and written by Cinco Paul and Ken Daurio .', 'Despicable_Me_2', 1, ['Illumination Entertainment', 'Universal Pictures', 'Cinco Paul', 'Chris Renaud (animator)', 'Illumination Mac Guff', 'Ken Daurio', 'Universal Studios', 'Pierre Coffin', 'Cinco Paul and Ken Daurio', 'Chris Renaud']]]
# [['Produced by Illumination Entertainment for Universal Pictures , and animated by Illumination Mac Guff , the film is directed by Pierre Coffin and Chris Renaud , and written by Cinco Paul and Ken Daurio .', 'Despicable_Me_2', 1, ['Illumination Entertainment', 'Universal Pictures', 'Cinco Paul', 'Chris Renaud (animator)', 'Illumination Mac Guff', 'Ken Daurio', 'Universal Studios', 'Pierre Coffin', 'Cinco Paul and Ken Daurio', 'Chris Renaud']]]
# On row 2882
# Label: REFUTES
# [['Their musical style encompassed the roots rock , swamp rock , and blues rock genres .', 'Creedence_Clearwater_Revival', 2, ['rock music', 'swamp rock', 'rock', 'blues rock', 'roots rock']], ['Despite their San Francisco Bay Area origins , they played in a Southern rock style , with lyrics about bayous , catfish , the Mississippi River , and other popular elements of Southern United States iconography , as well as political and socially-conscious lyrics about topics including the Vietnam War .', 'Creedence_Clearwater_Revival', 3, ['Mississippi River', 'rock music', 'Vietnam War', 'rock', 'Opposition to United States involvement in the Vietnam War', 'Southern rock', 'San Francisco Bay Area']], ['Creedence Clearwater Revival , often informally abbreviated to Creedence or CCR , was an American rock band active in the late 1960s and early 1970s .', 'Creedence_Clearwater_Revival', 0, ['rock', 'rock music']]]
# [['Their musical style encompassed the roots rock , swamp rock , and blues rock genres .', 'Creedence_Clearwater_Revival', 2, ['rock music', 'swamp rock', 'rock', 'blues rock', 'roots rock']], ['Despite their San Francisco Bay Area origins , they played in a Southern rock style , with lyrics about bayous , catfish , the Mississippi River , and other popular elements of Southern United States iconography , as well as political and socially-conscious lyrics about topics including the Vietnam War .', 'Creedence_Clearwater_Revival', 3, ['Mississippi River', 'rock music', 'Vietnam War', 'rock', 'Opposition to United States involvement in the Vietnam War', 'Southern rock', 'San Francisco Bay Area']], ['Creedence Clearwater Revival , often informally abbreviated to Creedence or CCR , was an American rock band active in the late 1960s and early 1970s .', 'Creedence_Clearwater_Revival', 0, ['rock', 'rock music']]]
# On row 1247
# Label: SUPPORTS
# [['Hominins , the earliest direct ancestors of the human clade , rose sometime during the latter part of the Miocene epoch ; the precise time marking the first hominins is broadly debated over a current range of 13 to 4 mya .', 'History_of_Earth', 19, ['Hominins', 'Miocene', 'first hominins', 'CHLCA']], ['Life remained mostly small and microscopic until about 580 million years ago , when complex multicellular life arose , developed over time , and culminated in the Cambrian Explosion about 541 million years ago .', 'History_of_Earth', 31, ['Cambrian Explosion', 'Timeline of human evolution#First living beings', 'multicellular life', 'Life', '580 million years ago', 'life', 'multicellular organism']], ['The plants and animals of the Miocene were fairly modern .', 'Miocene', 15, []], ['All species of animals , land plants and most fungi are multicellular , as are many algae , whereas a few organisms are partially uni - and partially multicellular , like slime molds and social amoebae such as the genus Dictyostelium .', 'Multicellular_organism', 3, ['Embryophyte', 'algae', 'Dictyostelium', 'fungi', 'land plants']], ['The earliest undisputed evidence of life on Earth dates at least from 3.5 billion years ago , during the Eoarchean Era after a geological crust started to solidify following the earlier molten Hadean Eon .', 'History_of_Earth', 24, ['Eon', 'geology', 'Eoarchean', 'Earth', 'geological', 'crust (geology)', 'Geologic time scale', 'crust', 'Hadean', 'life']], ['Various forms of life exist , such as plants , animals , fungi , protists , archaea , and bacteria .', 'Life', 1, ['fungi', 'bacteria', 'archaea', 'fungus']], ['This event drove a rapid diversification of life forms on Earth that produced most of the major phyla known today ; and it marked the end of the Proterozoic Eon and the beginning of the Cambrian Period of the Paleozoic Era .', 'History_of_Earth', 32, ['Eon', 'Geologic time scale', 'life', 'Earth']]]
# [['Hominins , the earliest direct ancestors of the human clade , rose sometime during the latter part of the Miocene epoch ; the precise time marking the first hominins is broadly debated over a current range of 13 to 4 mya .', 'History_of_Earth', 19, ['Hominins', 'Miocene', 'first hominins', 'CHLCA']], ['Life remained mostly small and microscopic until about 580 million years ago , when complex multicellular life arose , developed over time , and culminated in the Cambrian Explosion about 541 million years ago .', 'History_of_Earth', 31, ['Cambrian Explosion', 'Timeline of human evolution#First living beings', 'multicellular life', 'Life', '580 million years ago', 'life', 'multicellular organism']], ['The plants and animals of the Miocene were fairly modern .', 'Miocene', 15, []], ['All species of animals , land plants and most fungi are multicellular , as are many algae , whereas a few organisms are partially uni - and partially multicellular , like slime molds and social amoebae such as the genus Dictyostelium .', 'Multicellular_organism', 3, ['Embryophyte', 'algae', 'Dictyostelium', 'fungi', 'land plants']], ['The earliest undisputed evidence of life on Earth dates at least from 3.5 billion years ago , during the Eoarchean Era after a geological crust started to solidify following the earlier molten Hadean Eon .', 'History_of_Earth', 24, ['Eon', 'geology', 'Eoarchean', 'Earth', 'geological', 'crust (geology)', 'Geologic time scale', 'crust', 'Hadean', 'life']], ['Various forms of life exist , such as plants , animals , fungi , protists , archaea , and bacteria .', 'Life', 1, ['fungi', 'bacteria', 'archaea', 'fungus']], ['This event drove a rapid diversification of life forms on Earth that produced most of the major phyla known today ; and it marked the end of the Proterozoic Eon and the beginning of the Cambrian Period of the Paleozoic Era .', 'History_of_Earth', 32, ['Eon', 'Geologic time scale', 'life', 'Earth']]]
# On row 1408
# Label: SUPPORTS
# [['A total of 198 riders from 22 teams entered the 21-stage race , which was won by Chris Froome of .', '2016_Tour_de_France', 2, ['Chris Froome']]]
# [['A total of 198 riders from 22 teams entered the 21-stage race , which was won by Chris Froome of .', '2016_Tour_de_France', 2, ['Chris Froome']]]
# On row 987
# Label: REFUTES
# [['Wish Upon is a 2017 supernatural horror thriller film directed by John R. Leonetti and starring Joey King , Ryan Phillipe , Ki Hong Lee , Shannon Purser , Sydney Park and Sherilyn Fenn .', 'Wish_Upon', 0, ['Ki Hong Lee', 'Sherilyn Fenn', 'thriller film', 'supernatural horror film', 'Sydney Park', 'John R. Leonetti', 'Shannon Purser', 'supernatural horror', 'Sydney Park (actress)', 'Ryan Phillipe', 'Joey King']]]
# [['Wish Upon is a 2017 supernatural horror thriller film directed by John R. Leonetti and starring Joey King , Ryan Phillipe , Ki Hong Lee , Shannon Purser , Sydney Park and Sherilyn Fenn .', 'Wish_Upon', 0, ['Ki Hong Lee', 'Sherilyn Fenn', 'thriller film', 'supernatural horror film', 'Sydney Park', 'John R. Leonetti', 'Shannon Purser', 'supernatural horror', 'Sydney Park (actress)', 'Ryan Phillipe', 'Joey King']]]
# On row 1987
# Label: SUPPORTS
# [['Edgar Howard Wright -LRB- born 18 April 1974 -RRB- is an English director , screenwriter , producer , and actor .', 'Edgar_Wright', 0, []]]
# [['Edgar Howard Wright -LRB- born 18 April 1974 -RRB- is an English director , screenwriter , producer , and actor .', 'Edgar_Wright', 0, []]]
# On row 566
# Label: SUPPORTS
# [['He is best known for his books , including Deep Blues ; his music journalism for the New York Times and Rolling Stone magazine ; his work producing blues recordings and the soundtrack of the film Deep Blues ; and his clarinet playing in the 1960s band the Insect Trust .', 'Robert_Palmer_-LRB-writer-RRB-', 1, ['Deep Blues', 'The New York Times', 'soundtrack', 'New York', 'clarinet', 'Insect Trust', 'New York (state)', 'blues', 'The Insect Trust', 'Rolling Stone', 'Deep Blues: A Musical Pilgrimage to the Crossroads', 'New York Times']]]
# [['He is best known for his books , including Deep Blues ; his music journalism for the New York Times and Rolling Stone magazine ; his work producing blues recordings and the soundtrack of the film Deep Blues ; and his clarinet playing in the 1960s band the Insect Trust .', 'Robert_Palmer_-LRB-writer-RRB-', 1, ['Deep Blues', 'The New York Times', 'soundtrack', 'New York', 'clarinet', 'Insect Trust', 'New York (state)', 'blues', 'The Insect Trust', 'Rolling Stone', 'Deep Blues: A Musical Pilgrimage to the Crossroads', 'New York Times']]]
# On row 80
# Label: REFUTES
# [["The club is the second oldest of its kind still active in the country after Genoa 's football section -LRB- 1893 -RRB- , has traditionally worn a black and white striped home kit since 1903 and has played its home matches in several grounds , being the latest the 41,507-capacity Juventus Stadium .", 'Juventus_F.C.', 1, ['club', 'List of football clubs in Italy', 'Genoa', 'Genoa C.F.C.', 'Juventus Stadium']]]
# [["The club is the second oldest of its kind still active in the country after Genoa 's football section -LRB- 1893 -RRB- , has traditionally worn a black and white striped home kit since 1903 and has played its home matches in several grounds , being the latest the 41,507-capacity Juventus Stadium .", 'Juventus_F.C.', 1, ['club', 'List of football clubs in Italy', 'Genoa', 'Genoa C.F.C.', 'Juventus Stadium']]]
# On row 2899
# Label: SUPPORTS
# [['In 2017 , Graham became the first plus-size model to appear on the covers of British and American Vogue .', 'Ashley_Graham_-LRB-model-RRB-', 6, ['model', 'Vogue', 'Model (person)', 'Vogue (magazine)']], ["She has appeared on the cover of fashion magazines such as Vogue , Harper 's Bazaar , Glamour , and Elle .", 'Ashley_Graham_-LRB-model-RRB-', 1, ['Glamour', 'Elle', 'Vogue', 'Vogue (magazine)', 'Elle (magazine)', 'Glamour (magazine)']]]
# [['In 2017 , Graham became the first plus-size model to appear on the covers of British and American Vogue .', 'Ashley_Graham_-LRB-model-RRB-', 6, ['model', 'Vogue', 'Model (person)', 'Vogue (magazine)']], ["She has appeared on the cover of fashion magazines such as Vogue , Harper 's Bazaar , Glamour , and Elle .", 'Ashley_Graham_-LRB-model-RRB-', 1, ['Glamour', 'Elle', 'Vogue', 'Vogue (magazine)', 'Elle (magazine)', 'Glamour (magazine)']]]
# On row 3260
# Label: REFUTES
# [['Bell released an EP in 2011 called A Reminder independently .', 'Drake_Bell', 18, ['A Reminder']]]
# [['Bell released an EP in 2011 called A Reminder independently .', 'Drake_Bell', 18, ['A Reminder']]]
# On row 2410
# Label: REFUTES
# [['It was established on June 4 , 1992 after the Chechen-Ingush Autonomous Soviet Socialist Republic was split in two .', 'Ingushetia', 5, ['Chechen-Ingush Autonomous Soviet Socialist Republic', 'Ingush', 'Ingush people']]]
# [['It was established on June 4 , 1992 after the Chechen-Ingush Autonomous Soviet Socialist Republic was split in two .', 'Ingushetia', 5, ['Chechen-Ingush Autonomous Soviet Socialist Republic', 'Ingush', 'Ingush people']]]
# On row 2889
# Label: NOT ENOUGH INFO
# chilensis Mayr Rubilar, 2 †P.
# sandersi Ksepka, 2 and see text
# †P.
# mauretanicus Mourer-Chauviré Geraads, 2 †P.
# miocaenus Lartet, 1 †P.
# On row 224
# Label: REFUTES
# [['Nuuk -LRB- -LSB- nuːk -RSB- ; Godthåb -RRB- is the capital and largest city of Greenland and the municipality of Sermersooq .', 'Nuuk', 0, ['municipalities of Greenland', 'largest city', 'Sermersooq', 'List of cities and towns in Greenland', 'List of national capitals by latitude', 'capital', 'Greenland', 'municipality']]]
# [['Nuuk -LRB- -LSB- nuːk -RSB- ; Godthåb -RRB- is the capital and largest city of Greenland and the municipality of Sermersooq .', 'Nuuk', 0, ['municipalities of Greenland', 'largest city', 'Sermersooq', 'List of cities and towns in Greenland', 'List of national capitals by latitude', 'capital', 'Greenland', 'municipality']]]
# On row 349
# Label: REFUTES
# [['Artpop was the ninth best seller album of 2013 with 2.3 million copies worldwide .', 'Artpop', 15, []], ["The album received generally mixed reviews from music critics , but was commercially successful , debuting at number one on the United States Billboard 200 with first-week sales of 258,000 copies , becoming Gaga 's second consecutive number-one record in the United States and selling 757,000 copies .", 'Artpop', 13, ['Music journalism', 'music critics']]]
# [['Artpop was the ninth best seller album of 2013 with 2.3 million copies worldwide .', 'Artpop', 15, []], ["The album received generally mixed reviews from music critics , but was commercially successful , debuting at number one on the United States Billboard 200 with first-week sales of 258,000 copies , becoming Gaga 's second consecutive number-one record in the United States and selling 757,000 copies .", 'Artpop', 13, ['Music journalism', 'music critics']]]
# On row 1434
# Label: NOT ENOUGH INFO
# On return to the Western Front in early 1 it was broken up to provide reinforcements for other units.
# It was then sent to the Italian Front.
# The 32nd (Service) Battalion, Royal Fusiliers (East Ham) (32nd RF) was an infantry unit recruited as part of 'Kitchener's Army' in World War I.
# It served on the Western Front from May 1916, seeing action on the Somme and at Ypres.
# It was raised in the summer of 1 by the Mayor and Borough of East Ham in the Essex suburbs of London.
# On row 1284
# Label: REFUTES
# [['He is a collector of art and an active campaigner for the LGBT community , and is openly gay .', 'Roland_Emmerich', 3, ['openly', 'coming out', 'LGBT community']]]
# [['He is a collector of art and an active campaigner for the LGBT community , and is openly gay .', 'Roland_Emmerich', 3, ['openly', 'coming out', 'LGBT community']]]
# On row 156
# Label: NOT ENOUGH INFO
# After receiving a grant from the Australia Council Literature Board, Kelleher spent six months of 1 at the Kessing Writers' Studio in Paris.1 Many of the books he has written have been based on his childhood and his travels in Africa.
# While in New Zealand, he began writing part-time, prompted by homesickness for Africa.
# Kelleher was born in London1 and moved to Africa with his parents, at the age of fifteen.
# He has taught in Africa, New Zealand and Australia.
# He moved to Australia in 1976,2 with his South African wife, Alison, and was associate professor at the University of New England, in Armidale, New South Wales, before moving to Sydney to write full-time.
# On row 365
# Label: SUPPORTS
# [['McGraw has ventured into acting , with supporting roles in The Blind Side -LRB- with Sandra Bullock -RRB- , Friday Night Lights , The Kingdom , Tomorrowland , and Four Christmases -LRB- with Vince Vaughn and Reese Witherspoon -RRB- , and lead roles in Flicka -LRB- 2006 -RRB- and Country Strong -LRB- 2010 -RRB- .', 'Tim_McGraw', 13, ['Four Christmases', 'The Kingdom', 'Sandra Bullock', 'Tomorrowland (film)', 'Friday Night Lights (film)', 'Vince Vaughn', 'Reese Witherspoon', 'Flicka', 'The Kingdom (film)', 'Country Strong', 'Country', 'The Blind Side (film)', 'Friday Night Lights', 'The Blind Side', 'Country music', 'Tomorrowland']]]
# [['McGraw has ventured into acting , with supporting roles in The Blind Side -LRB- with Sandra Bullock -RRB- , Friday Night Lights , The Kingdom , Tomorrowland , and Four Christmases -LRB- with Vince Vaughn and Reese Witherspoon -RRB- , and lead roles in Flicka -LRB- 2006 -RRB- and Country Strong -LRB- 2010 -RRB- .', 'Tim_McGraw', 13, ['Four Christmases', 'The Kingdom', 'Sandra Bullock', 'Tomorrowland (film)', 'Friday Night Lights (film)', 'Vince Vaughn', 'Reese Witherspoon', 'Flicka', 'The Kingdom (film)', 'Country Strong', 'Country', 'The Blind Side (film)', 'Friday Night Lights', 'The Blind Side', 'Country music', 'Tomorrowland']]]
# On row 1132
# Label: NOT ENOUGH INFO
# In February 2020, the Carrick Furnace was purchased by the Path Valley Historical Society.
# Carrick Furnace is a historic iron furnace located at Metal Township in Franklin County, Pennsylvania.
# The furnace was built about 1828, and measures 3 feet square at the base and 3 feet high.
# https://pvhistoricalsociety.wixsite.com/pvhs 2
# The furnace went out of blast in 1884, and was donated to the Franklin County Historical Society-Kittochtinney in 1935.
# On row 700
# Label: NOT ENOUGH INFO
# Diplacodes haematodes, the scarlet percher, is a species of dragonfly in the family Libellulidae.3 It occurs throughout Australia (except Tasmania), Timor, New Guinea, Vanuatu, and New Caledonia.4 It is locally common in habitats with hot sunny exposed sites at or near rivers, streams, ponds, and lakes.
# Females have yellow infuscation suffusing the outer wings, while the males have similar colour at the bases of the wings.5
# It often prefers to settle on hot rocks rather than twigs or leaves, and is quite wary.
# The male is brilliant red, the female yellow-ochre.
# This is a spectacular species of dragonfly, although small in size (wingspan 60mm, length 35mm).
# On row 2566
# Label: REFUTES
# [['The deepwater field -LRB- defined as water depth 1300 to , -RRB- was discovered in September 2009 and it is operated by BP .', 'Tiber_Oil_Field', 1, ['BP']]]
# [['The deepwater field -LRB- defined as water depth 1300 to , -RRB- was discovered in September 2009 and it is operated by BP .', 'Tiber_Oil_Field', 1, ['BP']]]
# On row 8
# Label: REFUTES
# [['Savages is a 2012 American crime thriller film directed by Oliver Stone .', 'Savages_-LRB-2012_film-RRB-', 3, ['thriller', 'crime', 'Savages', 'Crime film', 'Oliver Stone', 'Savages (2010 novel)', 'Thriller (genre)']]]
# [['Savages is a 2012 American crime thriller film directed by Oliver Stone .', 'Savages_-LRB-2012_film-RRB-', 3, ['thriller', 'crime', 'Savages', 'Crime film', 'Oliver Stone', 'Savages (2010 novel)', 'Thriller (genre)']]]
# On row 2596
# Label: REFUTES
# [['Saturn is the sixth planet from the Sun and the second-largest in the Solar System , after Jupiter .', 'Saturn', 0, ['Saturn (mythology)', 'planet', 'Solar System', 'Sun', 'Jupiter', 'Saturn']]]
# [['Saturn is the sixth planet from the Sun and the second-largest in the Solar System , after Jupiter .', 'Saturn', 0, ['Saturn (mythology)', 'planet', 'Solar System', 'Sun', 'Jupiter', 'Saturn']]]
# On row 276
# Label: NOT ENOUGH INFO
# ...
# [['He was the first president to be born a United States citizen .', 'Martin_Van_Buren', 19, ['United States citizen', 'Natural-born-citizen clause']], ['Shortly after taking office , the Panic of 1837 struck the nation , and his inability to deal effectively with the economic crisis , combined with the growing political strength of the opposition Whig Party , led to his defeat in the 1840 presidential election .', 'Martin_Van_Buren', 3, ['Panic of 1837', 'United States presidential election, 1840', '1840 presidential election', 'Whig Party (United States)', 'Whig Party']], ['He then moved on Washington where he did more than anyone to construct the modern Democratic Party which dominated American politics down to the American Civil War .', 'Martin_Van_Buren', 6, ['modern Democratic Party', 'American Civil War', 'History of the Democratic Party (United States)', 'Democratic Party (United States)', 'Washington', 'Washington, D.C.', 'Democratic', 'Democratic Party']], ["Jackson and Van Buren were elected , and after serving as governor for two months , Van Buren resigned to become Jackson 's Secretary of State .", 'Martin_Van_Buren', 12, ['United States Secretary of State', 'Secretary of State']], ['A delegate to a political convention at age 18 , he quickly moved from local to state politics , gaining fame both as a political organizer and an accomplished lawyer .', 'Martin_Van_Buren', 9, ['state', 'U.S. state']], ["Van Buren 's nomination was rejected by the Senate , cutting short his service in London , but he was elected vice president in the 1832 election .", 'Martin_Van_Buren', 15, ['United States presidential election, 1832', '1832 election']], ['In New York he reorganized the Democratic-Republican Party and established the Albany Regency to keep it in power .', 'Martin_Van_Buren', 5, ['Democratic-Republican', 'New York', 'Democratic-Republican Party', 'Democratic Party (United States)', 'New York (state)', 'Albany Regency', 'Democratic']], ["Van Buren won the presidency by promising to continue Jackson 's policies .", 'Martin_Van_Buren', 2, []], ["As president , Van Buren was blamed for the depression of 1837 ; hostile newspapers called him `` Martin Van Ruin '' .", 'Martin_Van_Buren', 21, []], ['A member of the Democratic Party , he served in a number of other senior roles , including eighth Vice President -LRB- 1833 -- 37 -RRB- and tenth Secretary of State -LRB- 1829 -- 31 -RRB- , both under Andrew Jackson .', 'Martin_Van_Buren', 1, ['Vice President', 'Secretary of State', 'United States Secretary of State', 'Andrew Jackson', 'Democratic Party (United States)', 'Democratic', 'Vice President of the United States', 'Democratic Party']], ['During his half-century of public service , he built , perfected , and defended a new system of political parties at first the state and then the federal level .', 'Martin_Van_Buren', 4, ['state', 'U.S. state', 'United States federal government', 'federal']], ['Elected to the Senate by the New York State Legislature in 1821 , Van Buren supported William H. Crawford for president in the 1824 election , but by 1828 had come to support Jackson .', 'Martin_Van_Buren', 10, ['New York State Legislature', 'New York', 'William H. Crawford', '1824 election', 'United States presidential election, 1824', 'New York (state)', '1828', 'United States presidential election, 1828']], ['Martin Van Buren -LRB- Maarten van Buren ; December 5 , 1782 -- July 24 , 1862 -RRB- was an American politician who served as the eighth President of the United States -LRB- 1837 -- 41 -RRB- .', 'Martin_Van_Buren', 0, ['List of Presidents of the United States', 'politician', 'eighth President of the United States']]]
# On row 1150
# Label: NOT ENOUGH INFO
# Bukhara Prison is a fortified building that traditionally served as the prison of the Amir of Bukhara, in Uzbekistan.
# After the Bukhara Revolution, the collapse of the monarchy, and the formation of the Bukhara People's Soviet Republic, it was closed.
# Currently, it is considered one of the noteworthy places in the city.
# In the late 18th century, during the reign of the Mangits, it was built and was one of the largest prisons of the Bukhara Emirate.
# At the same time, the Museum of Legal and Judicial History of Bukhara is located here.1
# On row 1049
# Label: SUPPORTS
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# On row 142
# Label: SUPPORTS
# [["He made his film debut in the romantic comedy Coming Soon and became known by audiences in the comedy film Dude , Where 's My Car ?", 'Ashton_Kutcher', 2, ['Coming Soon (1999 film)', 'Coming Soon']]]
# [["He made his film debut in the romantic comedy Coming Soon and became known by audiences in the comedy film Dude , Where 's My Car ?", 'Ashton_Kutcher', 2, ['Coming Soon (1999 film)', 'Coming Soon']]]
# On row 99
# Label: NOT ENOUGH INFO
# The team also finished first in both the Atlantic Division and the Eastern Conference, and achieved the league's best record.
# The 6 wins were also the third-most in franchise history, behind the 1972– Celtics’ 6 wins and the famous 1985– Celtics’ 6 wins including 4 at home.
# Kevin Garnett was named NBA Defensive Player of the Year, while Danny Ainge, who executed "the most dramatic NBA turnaround ever", was named NBA Executive of the Year.1 The Celtics also sold out all 4 regular-season home games.
# Powered by the offseason blockbuster acquisitions of perennial All-Stars Kevin Garnett and Ray Allen to join with established star Paul Pierce, the trade enabled the Celtics to finish the season with a record of 66– in addition to posting the best single-season turnaround in NBA history.
# The 2007– Boston Celtics season was the 62nd season of the Boston Celtics in the National Basketball Association (NBA).
# On row 395
# Label: NOT ENOUGH INFO
# It was authorized by the United States Congress under the Internal Revenue Code, section 402A,1 and represents a unique combination of features of the Roth IRA and a traditional 401(k) plan.
# The same change in law allowed Roth IRA type contributions to 403(b) retirement plans.
# Since January 1, 2006, U.S. employers have been allowed to amend their 401(k) plan document to allow employees to elect Roth IRA type tax treatment for a portion or all of their retirement plan contributions.
# The Roth 401(k) is a type of retirement savings plan.
# The Roth retirement plan provision was enacted as a provision of the Economic Growth and Tax Relief Reconciliation Act of 2 (EGTRRA 2001).
# On row 1250
# Label: NOT ENOUGH INFO
# Kenlake State Resort Park is a park located on the western shore of Kentucky Lake.
# The park's main entrance and most of its facilities are located in Marshall County; the park also extends into Calloway County.
# The nearest town of substantial size is Murray.
# The park encompasses 1,7 acres (726ha) of land, 160,3 acres (64,900ha) of water, and features climate-controlled indoor tennis courts.2 It was Kentucky's first state resort park.3 Along with Lake Barkley State Resort Park and Kentucky Dam Village State Resort Park, Kenlake State Resort Park is part of the Land Between the Lakes National Recreation Area, originally organized by the Great Depression–era Tennessee Valley Authority (TVA).1
# The mailing address of the park is Hardin, Kentucky; however, it is located much closer to the unincorporated community of Aurora, Kentucky.
# On row 1310
# Label: NOT ENOUGH INFO
# Craicmore (krặk•mor) is a contemporary Celtic music band from Los Angeles, California, United States.
# As of 2013, the band consists of Nancy Johnston (lead vocals, percussion), John MacAdams (guitar, percussion, didgeridoo and backing vocals), Dave Champagne (bagpipes, woodwinds and backing vocals),1 and Sean Faye-Cullen (bass and backing vocals).
# Craicmore performs throughout the United States, and has toured internationally.
# Craicmore's music has been featured on TV shows like Without A Trace, How I Met Your Mother, and Days of Our Lives.
# The band is known for its original musical arrangements, built around traditional Irish and Scottish songs and tunes.
# On row 567
# Label: REFUTES
# [["The film treats themes of morality , greed , and the roles of lust , money , and luck in life , leading many to compare it to Allen 's earlier film Crimes and Misdemeanors -LRB- 1989 -RRB- .", 'Match_Point', 2, ['Crimes and Misdemeanors']]]
# [["The film treats themes of morality , greed , and the roles of lust , money , and luck in life , leading many to compare it to Allen 's earlier film Crimes and Misdemeanors -LRB- 1989 -RRB- .", 'Match_Point', 2, ['Crimes and Misdemeanors']]]
# On row 622
# Label: NOT ENOUGH INFO
# Hury Reservoir is a reservoir in County Durham, England situated in Baldersdale.
# The dam 'bridges' the River Balder which flows in an easterly direction to meet the River Tees at Cotherstone.
# It gets its name from the nearby village of Hury.
# It supplies water for Teesdale and is owned by Northumbrian Water.
# The reservoir is located about four miles south of Middleton-in-Teesdale and about three miles west of Cotherstone.
# On row 656
# Label: REFUTES
# [["It was founded as the Golden State Comic Book Convention in 1970 by a group of San Diegans that included Shel Dorf , Richard Alf , Ken Krueger and Mike Towry ; later , it was called the `` San Diego Comic Book Convention '' .", 'San_Diego_Comic-Con', 1, ['Mike Towry', 'Richard Alf', 'San Diego', 'Shel Dorf', 'Ken Krueger']]]
# [["It was founded as the Golden State Comic Book Convention in 1970 by a group of San Diegans that included Shel Dorf , Richard Alf , Ken Krueger and Mike Towry ; later , it was called the `` San Diego Comic Book Convention '' .", 'San_Diego_Comic-Con', 1, ['Mike Towry', 'Richard Alf', 'San Diego', 'Shel Dorf', 'Ken Krueger']]]
# On row 1328
# Label: NOT ENOUGH INFO
# The ceremony includes a symbolic washing and anointing, and receipt of a "new name" which they are not to reveal to others except at a certain part in the ceremony, and the receipt of the temple garment, which Mormons then are expected to wear under their clothing day and night throughout their life.
# In Mormonism, the endowment is a two-part ordinance (ceremony) designed for participants to become kings, queens, priests, and priestesses in the afterlife.
# All LDS Church members who choose to serve as missionaries or participate in a celestial marriage in a temple must first complete the first endowment ceremony.
# Participants are taught symbolic gestures and passwords considered necessary to pass by angels guarding the way to heaven, and are instructed not to reveal them to others.123 As practiced today in the Church of Jesus Christ of Latter-day Saints (LDS Church), the endowment also consists of a series of covenants (promises to God) that participants make, such as a covenant of consecration to the LDS Church.
# As part of the first ceremony, participants take part in a scripted reenactment of the Biblical creation and fall of Adam and Eve.
# On row 223
# Label: REFUTES
# [['Harvard is a large , highly residential research university .', 'Harvard_University', 15, ['research', 'research university']]]
# [['Harvard is a large , highly residential research university .', 'Harvard_University', 15, ['research', 'research university']]]
# On row 583
# Label: NOT ENOUGH INFO
# Clemson University represented the Atlantic Coast Conference (ACC) and Auburn University represented the Southeastern Conference (SEC) in the competition.
# The game was the final competition of the 2 football season for each team.
# With sponsorship from Chick-fil-A, it was the 40th edition of the game known throughout most of its history as the Peach Bowl.
# In exchange for the right to pick the first ACC team after the Bowl Championship Series selections, bowl representatives paid $3.25million to the ACC, while the SEC, whose fifth team was selected, received $2.4million.
# The combined $5.65million payout is the seventh-largest among all college football bowl games, and the fourth-largest non-BCS bowl game payout.
# On row 412
# Label: REFUTES
# [['At the 2010 census , the city population was 145,170 , and its metropolitan area had a population of 662,577 .', 'Syracuse,_New_York', 2, ['metropolitan area', 'United States Census 2010', 'Syracuse metropolitan area', 'city', '2010 census', 'City (New York)']]]
# [['At the 2010 census , the city population was 145,170 , and its metropolitan area had a population of 662,577 .', 'Syracuse,_New_York', 2, ['metropolitan area', 'United States Census 2010', 'Syracuse metropolitan area', 'city', '2010 census', 'City (New York)']]]
# On row 1123
# Label: NOT ENOUGH INFO
# Ken Rosewall was the only multiple singles champion, winning the title in 1 and 1976.
# The event was played as part of the USLTA Indoor Circuit from 1 through 19751 and became a World Championship Tennis event in 1976.
# It was played at the Mississippi Coliseum in Jackson, Mississippi in the United States until 1977.
# not part of a tennis tour or circuit.2 The tournament was played on indoor carpet courts.
# In its final year, 1977, it was an independent event, i.e.
# On row 96
# Label: NOT ENOUGH INFO
# In the period 1942-1973, he stood out for what he did at the amateur and semi-amateur level, in which he won 2 regional titles, won the Argentine Club Championship, and was South American runner-up in 1958.
# It is the only club that has been four-time and five-time champion of the National League.
# The team plays in the Liga Nacional de Básquet (LNB), which is the first tier level division of the Argentine basketball league system, and Pan-America's premier men's basketball league, the Basketball Champions League Americas.
# In addition, he was one of the founding clubs of the National League, playing the opening game of said tournament on April 26, 1985.
# San Lorenzo is the first, and so far, the only Argentine basketball team to face an NBA team.
# On row 536
# Label: NOT ENOUGH INFO
# It is a federally listed endangered species of the United States.
# Like other Hawaiian Melicope, this species is known as alani.2
# It is threatened by habitat loss.
# Melicope pallida, the pale melicope, is a species of tree in the family Rutaceae.
# It is endemic to the Hawaiian Islands.
# On row 1272
# Label: SUPPORTS
# [["In 1986 , O'Neal married professional tennis player John McEnroe , with whom she had three children .", "Tatum_O'Neal", 6, ['John McEnroe']]]
# [["In 1986 , O'Neal married professional tennis player John McEnroe , with whom she had three children .", "Tatum_O'Neal", 6, ['John McEnroe']]]
# On row 1086
# Label: REFUTES
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# [['Bessie Smith -LRB- April 15 , 1894 -- September 26 , 1937 -RRB- was an American blues singer .', 'Bessie_Smith', 0, ['blues', 'singer']]]
# Reached 100 supports and refutes. Stopping.

# %%
def load_jsonl(file_path, encoding='utf-8'):
    """Loads a JSON Lines file into a list of Python objects."""
    data = []
    try:
        with open(file_path, 'r', encoding=encoding) as f:
            for line in f:
                try:
                    data.append(json.loads(line))
                except json.JSONDecodeError:
                    print(f"Warning: Skipping invalid JSON line in {file_path}: {line.strip()}")
    except FileNotFoundError:
        print(f"ERROR: File not found at {file_path}")
        return None # Return None or empty list on error
    return data

# %%
# call the function to create a fine-tuning job for NLI stance classification
query_job_name = "GPT_query_paper_dev_train"
query_train_path = os.path.join(TRAIN_SAVE_DIR, 'prompt_v1_segmented_n200_balanced_04-27_002.jsonl')
query_val_path = os.path.join(VALID_SAVE_DIR, 'prompt_v1_segmented_n200_balanced_04-27_002.jsonl')
query_job_id = create_ft_job(query_job_name, query_train_path, query_val_path)
print(f"Fine-tuning job created with ID: {query_job_id}")
# Out:
# Fine-tuning job created with ID: ftjob-Z6TatIFHOaYBJHZhpDf2538i
