# %%
from google.colab import drive, userdata
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.7-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.11.3)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi==0.115.9 (from chromadb)
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-4.0.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.13.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.32.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.32.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.15.2)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.23.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.32.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.32.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-asgi==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.53b1)
# Collecting opentelemetry-util-http==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb) (0.30.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-1.0.7-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 68.9 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 81.4 MB/s eta 0:00:00
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.3 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 11.0 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.8 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 76.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.32.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.8 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl (7.3 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-4.0.1-py2.py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.7 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.2 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 31.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.5 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 87.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 31.5 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53800 sha256=a5a7d5b01462124fed2b1623661de33b139056ca3996b24ce7ff1078358a5dba
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, durationpy, uvloop, uvicorn, python-dotenv, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-exporter-otlp-proto-common, coloredlogs, build, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-1.0.7 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.9 httptools-0.6.4 humanfriendly-10.0 kubernetes-32.0.1 mmh3-5.1.0 onnxruntime-1.21.1 opentelemetry-exporter-otlp-proto-common-1.32.1 opentelemetry-exporter-otlp-proto-grpc-1.32.1 opentelemetry-instrumentation-0.53b1 opentelemetry-instrumentation-asgi-0.53b1 opentelemetry-instrumentation-fastapi-0.53b1 opentelemetry-proto-1.32.1 opentelemetry-util-http-0.53b1 overrides-7.7.0 posthog-4.0.1 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.1.0 starlette-0.45.3 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5

# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
import json
import nltk
import chromadb
import logging
import datetime
from sentence_transformers import SentenceTransformer
from tqdm import tqdm # Use notebook version for Colab
import uuid # Option for unique IDs, though combining page/chunk is better
import gc # Import garbage collector

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
# --- Configuration ---
BASE_DIR = '/content/drive/My Drive/SUNY_Poly_DSA598/' # Adjust as needed
WIKI_JSONL_DIR = os.path.join(BASE_DIR, 'datasets/FEVER/wiki-pages')
# Define where to store the persistent ChromaDB database
CHROMA_DB_PATH = os.path.join(BASE_DIR, 'chroma_db/fever_wiki_index_finetuned_debug') # Use a different path for debug runs if needed
# Path to your fine-tuned sBERT model
MODEL_PATH = os.path.join(BASE_DIR, 'models/sBERT/all-mpnet-base-v2_n1024_04-20_12:22_(ORCL_TEST)')
# If MODEL_PATH uses the specific name from your previous code:
# MODEL_PATH = f"{BASE_DIR}models/sBERT/all-mpnet-base-v2_n1024_04-20_12:22_(ORCL_TEST)"

COLLECTION_NAME = "fever_wiki_finetuned_sbert_debug"

# Chunking and Batching Parameters
SENTENCES_PER_CHUNK = 5       # How many sentences to group into one chunk
PROCESS_BATCH_SIZE = 64     # How many pages to process before embedding/adding to DB (adjust based on RAM)
MAX_FILES_TO_PROCESS = 1    # Set to a small number (e.g., 1) for debugging

# --- Setup Logging ---
# Logging setup remains useful even with debug prints for potential library/background messages
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# --- Helper Function for Chunking ---
def chunk_text_by_sentences(text, sentences_per_chunk):
    """Splits text into chunks of specified number of sentences."""
    sentences = nltk.sent_tokenize(text)
    chunks = []
    current_chunk_sentences = []
    for i, sentence in enumerate(sentences):
        current_chunk_sentences.append(sentence)
        if (i + 1) % sentences_per_chunk == 0:
            chunks.append(" ".join(current_chunk_sentences))
            current_chunk_sentences = []
    # Add any remaining sentences as the last chunk
    if current_chunk_sentences:
        chunks.append(" ".join(current_chunk_sentences))
    return chunks

# --- Core Processing Function (with Debug) ---
def process_page_batch(pages_batch, collection, sbert_model, sentences_per_chunk, debug=False):
    """
    Helper to chunk, embed, and add a batch of pages to ChromaDB.
    Includes debug printing.
    """
    if debug: print(f"[DEBUG] process_page_batch: Processing batch of {len(pages_batch)} pages.")
    batch_chunk_texts = []
    batch_chunk_ids = []
    batch_metadatas = []

    pages_processed_in_batch = 0
    for page_data in pages_batch:
        page_id = page_data['id']
        page_text = page_data['text']

        # Chunk the text
        chunks = chunk_text_by_sentences(page_text, sentences_per_chunk)
        if not chunks:
            logger.warning(f"Page {page_id} produced no text chunks, skipping.")
            if debug: print(f"[DEBUG] Page {page_id} produced no text chunks, skipping.")
            continue

        # Prepare data for this page's chunks
        for i, chunk_text in enumerate(chunks):
            chunk_id = f"{page_id}_chunk_{i}" # Unique ID for the chunk
            batch_chunk_texts.append(chunk_text)
            batch_chunk_ids.append(chunk_id)
            batch_metadatas.append({
                'page_id': page_id,       # Store original page title/ID
                'chunk_index': i,         # Store chunk sequence number
                'sentence_count': chunk_text.count('.') + chunk_text.count('?') + chunk_text.count('!') # Approx sentences
            })
        pages_processed_in_batch += 1

    # Embed all chunks in the batch together for efficiency
    if not batch_chunk_texts:
        if debug: print("[DEBUG] process_page_batch: No chunks generated in this batch.")
        return pages_processed_in_batch, 0 # No chunks generated in this batch

    try:
        # logger.debug(f"Embedding {len(batch_chunk_texts)} chunks...") # logger.debug might not show by default
        if debug: print(f"[DEBUG] process_page_batch: Embedding {len(batch_chunk_texts)} chunks...")
        # Convert to list of floats for ChromaDB compatibility if needed, depending on version/backend
        embeddings = sbert_model.encode(batch_chunk_texts, show_progress_bar=False).tolist()
        if debug: print(f"[DEBUG] process_page_batch: Embedding complete. Shape: {len(embeddings)} x {len(embeddings[0]) if embeddings else 0}")

        # Add batch to ChromaDB collection
        # Use upsert=True if you might re-run and want to overwrite existing IDs
        # logger.debug(f"Adding {len(batch_chunk_ids)} items to Chroma collection...")
        if debug: print(f"[DEBUG] process_page_batch: Adding {len(batch_chunk_ids)} items to Chroma collection '{collection.name}'...")
        collection.add(
            ids=batch_chunk_ids,
            embeddings=embeddings,
            metadatas=batch_metadatas,
            documents=batch_chunk_texts # Store the chunk text itself
        )
        if debug: print(f"[DEBUG] process_page_batch: Addition complete.")

        # Explicitly delete large variables to suggest garbage collection
        del embeddings
        del batch_chunk_texts
        del batch_chunk_ids
        del batch_metadatas
        gc.collect() # Suggest garbage collection
        if debug: print(f"[DEBUG] process_page_batch: Cleaned up batch variables.")

        return pages_processed_in_batch, len(chunks) * pages_processed_in_batch # Return estimate based on pages processed

    except Exception as e:
        logger.error(f"Error during embedding or adding batch to ChromaDB: {e}")
        if debug: print(f"[ERROR] process_page_batch: Error during embedding or adding batch: {e}")
        # Decide how to handle partial failures - skip batch, retry?
        return pages_processed_in_batch, 0 # Report 0 chunks added for this failed batch

# --- Main Indexing Function (with Debug) ---
def build_chroma_index_incrementally(wiki_dir, db_path, collection_name, model_path,
                                     sentences_per_chunk=5, process_batch_size=32,
                                     max_files=None, debug=False):
    """
    Loads wiki pages, chunks text, embeds, and builds a persistent ChromaDB index incrementally.
    Includes debug printing.
    """
    if debug: print(f"[DEBUG] Starting build_chroma_index_incrementally with debug mode ENABLED.")

    if not os.path.exists(wiki_dir):
        logger.error(f"Wikipedia JSONL directory not found: {wiki_dir}")
        if debug: print(f"[ERROR] Wikipedia JSONL directory not found: {wiki_dir}")
        return

    # --- Initialize ChromaDB Client (Persistent) ---
    logger.info(f"Initializing persistent ChromaDB client at: {db_path}")
    if debug: print(f"[DEBUG] Initializing persistent ChromaDB client at: {db_path}")
    os.makedirs(db_path, exist_ok=True) # Ensure directory exists
    try:
        client = chromadb.PersistentClient(path=db_path)
        if debug: print(f"[DEBUG] ChromaDB client initialized.")
    except Exception as e:
        logger.error(f"Failed to initialize ChromaDB client: {e}")
        if debug: print(f"[ERROR] Failed to initialize ChromaDB client: {e}")
        return

    # --- Load Sentence Transformer Model ---
    logger.info(f"Loading sBERT model from: {model_path}")
    if debug: print(f"[DEBUG] Loading sBERT model from: {model_path}")
    try:
        # Ensure model runs on GPU if available (implicitly handled by SentenceTransformer usually)
        sbert_model = SentenceTransformer(model_path) # Specify device if needed
        if debug: print(f"[DEBUG] sBERT model loaded successfully.")
    except Exception as e:
        logger.error(f"Failed to load Sentence Transformer model: {e}")
        if debug: print(f"[ERROR] Failed to load Sentence Transformer model: {e}")
        return

    # --- Get or Create Chroma Collection ---
    logger.info(f"Getting or creating ChromaDB collection: {collection_name}")
    if debug: print(f"[DEBUG] Getting or creating ChromaDB collection: {collection_name}")
    try:
        collection = client.get_or_create_collection(
            name=collection_name,
            # metadata={"hnsw:space": "cosine"} # Optional: Specify distance metric
        )
        initial_count = collection.count()
        logger.info(f"Collection '{collection_name}' ready. Current count: {initial_count}")
        if debug: print(f"[DEBUG] Collection '{collection_name}' ready. Current count: {initial_count}")
    except Exception as e:
        logger.error(f"Failed to get or create ChromaDB collection: {e}")
        if debug: print(f"[ERROR] Failed to get or create ChromaDB collection: {e}")
        return


    # --- Iterate through wiki files ---
    wiki_files = sorted([f for f in os.listdir(wiki_dir) if f.startswith('wiki-') and f.endswith('.jsonl')])
    if max_files is not None:
        wiki_files = wiki_files[:max_files]
    logger.info(f"Found {len(wiki_files)} wiki files to process.")
    if debug: print(f"[DEBUG] Found {len(wiki_files)} wiki files to process.")

    total_pages_processed = 0
    total_chunks_added = 0

    # Use tqdm for progress bar over files
    for filename in tqdm(wiki_files, desc="Processing Wiki Files"):
        filepath = os.path.join(wiki_dir, filename)
        logger.info(f"Processing file: {filename}")
        if debug: print(f"\n[DEBUG] Processing file: {filename} at path: {filepath}")

        pages_batch = [] # Accumulate pages before processing
        file_pages_processed = 0
        file_chunks_added = 0

        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                # Use tqdm for progress within a file (can be verbose)
                # for line_num, line in tqdm(enumerate(f), desc=f"Lines in {filename}", leave=False): # Optionally add inner progress
                f_len = sum(1 for _ in f) # Get file length
                f.seek(0) # Reset file pointer

                for line_num, line in enumerate(f):
                    try:
                        data = json.loads(line)
                        page_id = str(data.get('id', '')) # Ensure ID is string
                        page_text = data.get('text', '')

                        if not page_id or not page_text:
                            # logger.warning(f"Skipping line {line_num+1} in {filename}: Missing 'id' or 'text'.")
                            # Optional: Add debug print for skipped lines if needed
                            if debug: print(f"[DEBUG] Skipping line {line_num+1} in {filename}: Missing 'id' or 'text'.")
                            continue

                        if debug: print(f"[DEBUG] Processing line {line_num+1} of {f_len} in {filename}.")
                        pages_batch.append({'id': page_id, 'text': page_text})

                        # When batch is full, process it
                        if len(pages_batch) >= process_batch_size:
                            if debug: print(f"[DEBUG] Reached batch size ({process_batch_size}), processing batch...")
                            processed_count, chunks_count = process_page_batch(pages_batch, collection, sbert_model, sentences_per_chunk, debug=debug)
                            file_pages_processed += processed_count
                            file_chunks_added += chunks_count
                            pages_batch = [] # Reset batch
                            if debug: print(f"[DEBUG] Batch processed. File pages so far: {file_pages_processed}, File chunks so far: {file_chunks_added}")


                    except json.JSONDecodeError:
                        logger.warning(f"Skipping invalid JSON line {line_num+1} in {filename}.")
                        if debug: print(f"[WARN] Skipping invalid JSON line {line_num+1} in {filename}.")
                    except Exception as e:
                        logger.error(f"Error processing line {line_num+1} in {filename}: {e}")
                        if debug: print(f"[ERROR] Error processing line {line_num+1} in {filename}: {e}")

                # Process any remaining pages in the last batch for this file
                if pages_batch:
                    if debug: print(f"[DEBUG] Processing final batch for file {filename} (size: {len(pages_batch)})...")
                    processed_count, chunks_count = process_page_batch(pages_batch, collection, sbert_model, sentences_per_chunk, debug=debug)
                    file_pages_processed += processed_count
                    file_chunks_added += chunks_count
                    if debug: print(f"[DEBUG] Final batch processed.")


        except Exception as e:
            logger.error(f"Error reading or processing file {filename}: {e}")
            if debug: print(f"[ERROR] Error reading or processing file {filename}: {e}")

        total_pages_processed += file_pages_processed
        total_chunks_added += file_chunks_added
        logger.info(f"Finished processing {filename}. Pages in file: {file_pages_processed}, Chunks added: {file_chunks_added}. Total pages overall: {total_pages_processed}, Total chunks overall: {total_chunks_added}")
        if debug: print(f"[DEBUG] Finished processing {filename}. Pages in file: {file_pages_processed}, Chunks added: {file_chunks_added}. Cumulative pages: {total_pages_processed}, Cumulative chunks: {total_chunks_added}")
        # Optional: Persist aggressively after each file if memory is extremely tight, though PersistentClient should handle it.
        # client.persist()
        # if debug: print(f"[DEBUG] Explicitly persisted DB state after file {filename}")


    logger.info(f"--- Indexing complete ---")
    if debug: print(f"\n--- [DEBUG] Indexing complete ---")
    logger.info(f"Total Wikipedia pages processed: {total_pages_processed}")
    if debug: print(f"[DEBUG] Total Wikipedia pages processed: {total_pages_processed}")
    logger.info(f"Total text chunks added to collection '{collection_name}': {total_chunks_added}")
    if debug: print(f"[DEBUG] Total text chunks added to collection '{collection_name}': {total_chunks_added}")
    final_count = collection.count()
    logger.info(f"Final collection count: {final_count}")
    if debug: print(f"[DEBUG] Final collection count: {final_count}")
    logger.info(f"Database saved to: {db_path}")
    if debug: print(f"[DEBUG] Database saved to: {db_path}")


# --- Code to Run in Notebook Cell ---

# Make sure MODEL_PATH is correctly set before running
if "YYYY-MM-DD" in MODEL_PATH: # Basic check if placeholder is still there
     print("ERROR: Please update MODEL_PATH with the correct path to your fine-tuned model.")
     # Or raise an error: raise ValueError("MODEL_PATH needs to be updated.")
else:
    # Set debug=True for the main call
    build_chroma_index_incrementally(
        wiki_dir=WIKI_JSONL_DIR,
        db_path=CHROMA_DB_PATH,
        collection_name=COLLECTION_NAME,
        model_path=MODEL_PATH,
        sentences_per_chunk=SENTENCES_PER_CHUNK,
        process_batch_size=PROCESS_BATCH_SIZE,
        max_files=MAX_FILES_TO_PROCESS,
        debug=True # <--- Set Debug Mode Here
    )
# Out:
# [DEBUG] Starting build_chroma_index_incrementally with debug mode ENABLED.
# [DEBUG] Initializing persistent ChromaDB client at: /content/drive/My Drive/SUNY_Poly_DSA598/chroma_db/fever_wiki_index_finetuned_debug
# [DEBUG] ChromaDB client initialized.
# [DEBUG] Loading sBERT model from: /content/drive/My Drive/SUNY_Poly_DSA598/models/sBERT/all-mpnet-base-v2_n1024_04-20_12:22_(ORCL_TEST)
# [DEBUG] sBERT model loaded successfully.
# [DEBUG] Getting or creating ChromaDB collection: fever_wiki_finetuned_sbert_debug
# [DEBUG] Collection 'fever_wiki_finetuned_sbert_debug' ready. Current count: 0
# [DEBUG] Found 1 wiki files to process.
# Processing Wiki Files:   0%|          | 0/1 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# [DEBUG] Processing line 44157 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44158 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44159 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44160 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44161 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44162 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44163 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44164 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44165 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44166 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44167 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44168 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 71 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 71 x 768
# [DEBUG] process_page_batch: Adding 71 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42624, File chunks so far: 51200
# [DEBUG] Processing line 44169 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44170 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44171 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44172 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44173 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44174 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44175 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44176 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44177 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44178 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44179 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44180 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44181 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44182 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44183 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44184 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44185 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44186 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44187 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44188 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44189 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44190 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44191 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44192 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44193 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44194 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44195 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44196 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44197 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44198 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44199 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44200 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44201 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44202 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44203 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44204 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44205 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44206 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44207 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44208 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44209 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44210 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44211 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44212 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44213 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44214 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44215 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44216 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44217 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44218 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44219 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44220 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44221 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44222 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44223 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44224 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44225 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44226 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44227 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44228 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44229 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44230 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44231 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44232 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44233 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 73 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 73 x 768
# [DEBUG] process_page_batch: Adding 73 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42688, File chunks so far: 51264
# [DEBUG] Processing line 44234 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44235 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44236 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44237 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44238 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44239 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44240 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44241 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44242 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44243 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44244 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44245 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44246 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44247 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44248 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44249 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44250 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44251 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44252 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44253 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44254 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44255 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44256 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44257 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44258 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44259 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44260 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44261 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44262 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44263 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44264 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44265 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44266 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44267 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44268 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44269 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44270 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44271 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44272 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44273 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44274 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44275 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44276 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44277 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44278 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44279 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44280 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44281 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44282 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44283 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44284 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44285 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44286 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44287 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44288 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44289 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44290 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44291 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44292 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44293 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44294 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44295 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44296 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44297 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44298 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 87 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 87 x 768
# [DEBUG] process_page_batch: Adding 87 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42752, File chunks so far: 51328
# [DEBUG] Processing line 44299 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44300 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44301 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44302 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44303 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44304 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44305 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44306 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44307 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44308 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44309 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44310 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44311 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44312 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44313 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44314 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44315 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44316 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44317 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44318 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44319 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44320 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44321 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44322 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44323 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44324 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44325 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44326 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44327 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44328 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44329 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44330 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44331 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44332 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44333 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44334 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44335 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44336 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44337 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44338 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44339 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44340 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44341 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44342 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44343 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44344 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44345 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44346 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44347 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44348 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44349 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44350 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44351 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44352 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44353 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44354 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44355 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44356 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44357 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44358 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44359 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44360 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44361 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44362 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44363 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 77 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 77 x 768
# [DEBUG] process_page_batch: Adding 77 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42816, File chunks so far: 51392
# [DEBUG] Processing line 44364 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44365 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44366 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44367 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44368 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44369 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44370 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44371 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44372 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44373 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44374 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44375 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44376 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44377 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44378 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44379 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44380 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44381 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44382 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44383 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44384 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44385 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44386 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44387 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44388 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44389 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44390 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44391 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44392 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44393 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44394 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44395 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44396 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44397 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44398 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44399 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44400 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44401 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44402 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44403 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44404 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44405 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44406 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44407 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44408 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44409 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44410 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44411 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44412 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44413 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44414 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44415 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44416 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44417 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44418 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44419 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44420 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44421 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44422 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44423 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44424 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44425 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44426 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44427 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44428 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44429 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 82 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 82 x 768
# [DEBUG] process_page_batch: Adding 82 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42880, File chunks so far: 51520
# [DEBUG] Skipping line 44430 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44431 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44432 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44433 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44434 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44435 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44436 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44437 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44438 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44439 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44440 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44441 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44442 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44443 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44444 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44445 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44446 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44447 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44448 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44449 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44450 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44451 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44452 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44453 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44454 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44455 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44456 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44457 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44458 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44459 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44460 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44461 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44462 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44463 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44464 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44465 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44466 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44467 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44468 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44469 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44470 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44471 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44472 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44473 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44474 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44475 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44476 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44477 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44478 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44479 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44480 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44481 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44482 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44483 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44484 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44485 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44486 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44487 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44488 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44489 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44490 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44491 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44492 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44493 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44494 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44495 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44496 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44497 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44498 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 74 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 74 x 768
# [DEBUG] process_page_batch: Adding 74 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 42944, File chunks so far: 51584
# [DEBUG] Processing line 44499 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44500 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44501 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44502 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44503 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44504 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44505 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44506 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44507 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44508 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44509 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44510 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44511 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44512 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44513 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44514 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44515 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44516 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44517 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44518 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44519 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44520 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44521 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44522 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44523 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44524 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44525 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44526 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44527 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44528 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44529 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44530 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44531 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44532 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44533 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44534 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44535 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44536 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44537 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44538 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44539 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44540 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44541 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44542 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44543 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44544 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44545 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44546 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44547 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44548 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44549 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44550 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44551 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44552 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44553 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44554 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44555 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44556 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44557 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44558 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44559 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44560 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44561 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44562 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44563 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44564 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44565 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 84 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 84 x 768
# [DEBUG] process_page_batch: Adding 84 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 43008, File chunks so far: 51712
# [DEBUG] Processing line 44566 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44567 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44568 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44569 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44570 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44571 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44572 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44573 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44574 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44575 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44576 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44577 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44578 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44579 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44580 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44581 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44582 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44583 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44584 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44585 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44586 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44587 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44588 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44589 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44590 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44591 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44592 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44593 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44594 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44595 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44596 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44597 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44598 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44599 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44600 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44601 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44602 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44603 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44604 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44605 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44606 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44607 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44608 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44609 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44610 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44611 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44612 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44613 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44614 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44615 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44616 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44617 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44618 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44619 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44620 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44621 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44622 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44623 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44624 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44625 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44626 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44627 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44628 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44629 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44630 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44631 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44632 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 79 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 79 x 768
# [DEBUG] process_page_batch: Adding 79 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 43072, File chunks so far: 51776
# [DEBUG] Processing line 44633 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44634 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44635 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44636 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44637 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44638 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44639 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44640 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44641 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44642 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44643 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44644 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44645 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44646 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44647 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44648 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44649 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44650 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44651 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44652 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44653 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44654 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44655 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44656 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44657 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44658 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44659 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44660 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44661 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44662 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44663 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44664 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44665 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44666 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44667 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44668 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44669 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44670 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44671 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44672 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44673 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44674 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44675 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44676 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44677 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44678 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44679 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44680 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44681 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44682 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44683 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44684 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44685 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44686 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44687 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44688 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44689 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44690 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44691 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44692 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44693 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44694 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44695 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44696 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44697 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44698 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44699 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 75 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 75 x 768
# [DEBUG] process_page_batch: Adding 75 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 43136, File chunks so far: 51840
# [DEBUG] Processing line 44700 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44701 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44702 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44703 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44704 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44705 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44706 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44707 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44708 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44709 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44710 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44711 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44712 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44713 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44714 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44715 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44716 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44717 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44718 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44719 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44720 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44721 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44722 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44723 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44724 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44725 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44726 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44727 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44728 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44729 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44730 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44731 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44732 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Skipping line 44733 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44734 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44735 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44736 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44737 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44738 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44739 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44740 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44741 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44742 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44743 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44744 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44745 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44746 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44747 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44748 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44749 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44750 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44751 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44752 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44753 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44754 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44755 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44756 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44757 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44758 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44759 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44760 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44761 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44762 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44763 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44764 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44765 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44766 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44767 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 76 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 76 x 768
# [DEBUG] process_page_batch: Adding 76 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 43200, File chunks so far: 51904
# [DEBUG] Processing line 44768 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44769 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44770 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44771 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44772 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44773 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44774 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44775 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44776 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44777 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44778 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44779 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44780 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44781 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44782 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44783 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44784 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44785 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44786 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44787 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44788 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44789 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44790 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44791 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44792 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44793 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44794 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44795 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44796 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44797 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44798 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44799 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44800 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44801 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44802 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44803 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44804 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44805 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44806 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44807 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44808 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44809 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44810 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44811 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44812 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44813 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44814 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44815 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44816 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44817 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44818 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44819 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44820 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44821 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44822 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44823 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44824 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44825 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44826 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44827 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44828 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44829 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44830 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44831 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 74 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 74 x 768
# [DEBUG] process_page_batch: Adding 74 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 43264, File chunks so far: 51968
# [DEBUG] Processing line 44832 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44833 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44834 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44835 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44836 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44837 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44838 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44839 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44840 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44841 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44842 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44843 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44844 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44845 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44846 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44847 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 44848 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 44849 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44850 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44851 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44852 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44853 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44854 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44855 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44856 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44857 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44858 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44859 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44860 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44861 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44862 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44863 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44864 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44865 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44866 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44867 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 44868 of 50000 in wiki-001.jsonl.
# ...
# [DEBUG] Processing line 48374 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48375 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48376 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48377 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48378 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48379 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48380 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48381 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48382 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48383 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48384 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48385 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48386 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48387 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48388 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48389 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48390 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48391 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48392 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48393 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48394 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48395 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48396 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48397 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48398 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48399 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48400 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48401 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48402 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48403 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48404 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48405 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48406 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48407 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48408 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48409 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48410 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48411 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48412 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48413 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48414 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48415 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 76 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 76 x 768
# [DEBUG] process_page_batch: Adding 76 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 46720, File chunks so far: 56192
# [DEBUG] Processing line 48416 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48417 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48418 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48419 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48420 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48421 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48422 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48423 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48424 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48425 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48426 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48427 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48428 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48429 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48430 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48431 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48432 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48433 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48434 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48435 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48436 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48437 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48438 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48439 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48440 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48441 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48442 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48443 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48444 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48445 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48446 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48447 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48448 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48449 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48450 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48451 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48452 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48453 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48454 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48455 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48456 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48457 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48458 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48459 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48460 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48461 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48462 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48463 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48464 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48465 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48466 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48467 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48468 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48469 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48470 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48471 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48472 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48473 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48474 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48475 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48476 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48477 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48478 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48479 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48480 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48481 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48482 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 73 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 73 x 768
# [DEBUG] process_page_batch: Adding 73 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 46784, File chunks so far: 56256
# [DEBUG] Skipping line 48483 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48484 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48485 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48486 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48487 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48488 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48489 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48490 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48491 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48492 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48493 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48494 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48495 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48496 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48497 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48498 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48499 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48500 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48501 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48502 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48503 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48504 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48505 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48506 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48507 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48508 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48509 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48510 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48511 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48512 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48513 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48514 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48515 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48516 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48517 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48518 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48519 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48520 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48521 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48522 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48523 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48524 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48525 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48526 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48527 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48528 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48529 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48530 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48531 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48532 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48533 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48534 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48535 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48536 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48537 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48538 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48539 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48540 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48541 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48542 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48543 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48544 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48545 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48546 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48547 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48548 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 79 chunks...
# [DEBUG] process_page_batch: Embedding complete. Shape: 79 x 768
# [DEBUG] process_page_batch: Adding 79 items to Chroma collection 'fever_wiki_finetuned_sbert_debug'...
# [DEBUG] process_page_batch: Addition complete.
# [DEBUG] process_page_batch: Cleaned up batch variables.
# [DEBUG] Batch processed. File pages so far: 46848, File chunks so far: 56384
# [DEBUG] Processing line 48549 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48550 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48551 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48552 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48553 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48554 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48555 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48556 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48557 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48558 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48559 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48560 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48561 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48562 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48563 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48564 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48565 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48566 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48567 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48568 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48569 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48570 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48571 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48572 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48573 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48574 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48575 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48576 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48577 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48578 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48579 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48580 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48581 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48582 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48583 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48584 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48585 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48586 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48587 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48588 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48589 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48590 of 50000 in wiki-001.jsonl.
# [DEBUG] Skipping line 48591 in wiki-001.jsonl: Missing 'id' or 'text'.
# [DEBUG] Processing line 48592 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48593 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48594 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48595 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48596 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48597 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48598 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48599 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48600 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48601 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48602 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48603 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48604 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48605 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48606 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48607 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48608 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48609 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48610 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48611 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48612 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48613 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48614 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48615 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48616 of 50000 in wiki-001.jsonl.
# [DEBUG] Processing line 48617 of 50000 in wiki-001.jsonl.
# [DEBUG] Reached batch size (64), processing batch...
# [DEBUG] process_page_batch: Processing batch of 64 pages.
# [DEBUG] process_page_batch: Embedding 94 chunks...
